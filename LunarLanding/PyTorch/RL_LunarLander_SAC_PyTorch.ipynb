# %% [markdown]
# # RL LunarLander: Actor-Critic SAC  with Pytorch

# %%
import numpy as np
import gym
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import random

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from collections import deque, namedtuple
import time
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import os
cpu_count = os.cpu_count()
print(f"CPU count: {cpu_count}")
torch.set_num_threads(cpu_count)
print(f"PyTorch threads: {torch.get_num_threads()}")
print(f"PyTorch device: {device}")
# Out:
# CPU count: 12
# PyTorch threads: 12
# PyTorch device: cpu

# %%
# Environmental global variables:
SEED = 42

# Making the environment:
env = gym.make('LunarLander-v2')
#env = gym.make('CartPole-v1')
env.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
random.seed(SEED)
env.action_space.seed(SEED)  # Ensures deterministic action sampling

# Hyperparameters:
learning_rate = 0.0001
gamma = 0.99
num_episodes = 1500
TAU = 0.01
replay_memory_capacity = int(1e5)
batch_size = 100
MEMORY_SIZE = int(1e5)
frequency_update = 2



# Defining the neural network:
space_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
print(f"Space_dim: {space_dim}, Action_dim: {action_dim}")


class Actor_Model(nn.Module):
    def __init__(self, state_size, action_size):
        super(Actor_Model, self).__init__()
        self.seed = torch.manual_seed(SEED)
        self.fc1 = nn.Linear(state_size, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, action_size)

    def forward(self, state):
        state = F.relu(self.fc1(state))
        state = F.relu(self.fc2(state))
        action_probabilities = F.softmax(self.fc3(state), dim=1)
        return action_probabilities
    
    
class Critic_Model(nn.Module):
    def __init__(self, state_size, action_size):
        super(Critic_Model, self).__init__()
        self.seed = torch.manual_seed(SEED)
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)    
        self.fc3 = nn.Linear(64, action_size)             # Output is a single value (V(s) value)

    def forward(self, state):
        state = F.relu(self.fc1(state))
        state = F.relu(self.fc2(state))
        state_value = self.fc3(state)
        return state_value
    
    
    
# Defining the ReplayBuffer
class ReplayBuffer:
    def __init__(self, buffer_size, action_size):
        self.seed = random.seed(SEED)
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)
        self.experiences = namedtuple("Experiences", field_names=["state","action","reward","new_state", "done"])
        
    def add(self, state, action, reward, new_state, done):
        e = self.experiences(state, action, reward, new_state, done)
        self.memory.append(e)
        
    def sample(self, batch_size):
        experiences = random.sample(self.memory, k=batch_size)
        
        states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(device)
        actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(device)
        rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(device)
        new_states = torch.from_numpy(np.vstack([e.new_state for e in experiences if e is not None])).float().to(device)
        dones = torch.from_numpy(np.vstack([e.done for e in experiences if e is not None]).astype(np.uint8)).float().to(device)
        
        return states, actions, rewards, new_states, dones
    
    def __len__(self):
        return len(self.memory)



class SACAgent:
    def __init__(self, state_size, action_size):
        self.t_step = 0
        self.tau = TAU
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.num_episodes = num_episodes

        self.seed = random.seed(SEED)
        self.state_size = state_size
        self.action_size = action_size
        self.update_frequency = frequency_update

        self.memory = ReplayBuffer(buffer_size=MEMORY_SIZE,action_size=action_size)

        # Actor Network
        self.actor_nn = Actor_Model(state_size=state_size, action_size=action_size).to(device)
        self.optimizer_actor = optim.Adam(self.actor_nn.parameters(), lr=self.learning_rate)

        # Critic Networks
        self.critic1_online_nn = Critic_Model(state_size=state_size, action_size=action_size).to(device)
        self.critic1_target_nn = Critic_Model(state_size=state_size, action_size=action_size).to(device)
        self.optimizer_critic1_local = optim.Adam(self.critic1_online_nn.parameters(), lr=self.learning_rate)

        # Entropy Parameters
        self.alpha_entropy = 0.0
        

    def choose_action(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action_probs = self.actor_nn(state_tensor)
        action_dist = torch.distributions.Categorical(action_probs)
        action = action_dist.sample().item()
        return action
    
    def step(self, state, action, reward, next_state, done):
        self.memory.add(state=state,action=action, reward=reward,new_state=next_state,done=done)

        self.t_step = (self.t_step + 1) % self.update_frequency
        update_flag = self.t_step == 0
        if update_flag:
            if self.memory.__len__() > self.batch_size:
                experiences = self.memory.sample(batch_size=self.batch_size)
                self.learn(experiences)

    def learn(self, experiences):
        states, actions, rewards, next_states, dones = experiences

        # Update the critic networks
        self.update_critic(states, actions, rewards, next_states, dones)

        # Update the actor network
        self.update_actor(states, actions)

        # Update the target networks
        self.soft_update(critic_model_online=self.critic1_online_nn, critic_model_target=self.critic1_target_nn)


    def update_critic(self, states, actions, rewards, next_states, dones):
        #print(f"\n ======================================== Update Critic ======================================== \n")
        with torch.no_grad():
            next_action_probs = self.actor_nn(next_states)
            next_log_probs = torch.log(next_action_probs + 1e-7)

            q_next = self.critic1_target_nn(next_states)
            q_next_expected = (next_action_probs * (q_next - self.alpha_entropy * next_log_probs)).sum(dim=1, keepdim=True)

            y_target = rewards + self.gamma * (1 - dones) * q_next_expected
            #print(f"Shape of y_target: {y_target.shape}")

        # Step 2: Compute the Q values for the current state
        q_values_current = self.critic1_online_nn(states).gather(1, actions)
        #print(f"Shape of q_values_current: {q_values_current.shape}")
      


        # Compute critic loss
        critic_loss = F.mse_loss(q_values_current, y_target)

        # Update the critic
        self.optimizer_critic1_local.zero_grad()
        critic_loss.backward()
        self.optimizer_critic1_local.step()
        


    def update_actor(self, states, actions):
        #print(f"\n ======================================== Update Actor ======================================== \n")

        probs = self.actor_nn(states)
        log_probs = torch.log(probs + 1e-7)  
        entropy_part = self.alpha_entropy * log_probs
        entropy_part_final = entropy_part.sum(dim=1, keepdim=True)

        q_values = self.critic1_online_nn(states)
        weighted_q = (probs * q_values).sum(dim=1, keepdim=True)  # Expectation under policy

        actor_loss = (self.alpha_entropy * log_probs - weighted_q).mean()

        self.optimizer_actor.zero_grad()
        actor_loss.backward()
        self.optimizer_actor.step()



    
    def soft_update(self, critic_model_online, critic_model_target):
        """
        Apply soft update to the target critic model using the online critic model.
        
        Args:
            self: The current instance of the class (which has critic networks).
            critic_model_online: The online critic model (current model).
            critic_model_target: The target critic model (the one to be updated).
        """
        with torch.no_grad():
            # Apply soft update to the target critic network
            for target_param, online_param in zip(critic_model_target.parameters(), critic_model_online.parameters()):
                target_param.data.copy_((1 - self.tau) * target_param.data + self.tau * online_param.data)





def plot_training(mean_rewards_list, total_rewards_list):
    # Use Seaborn to plot rewards per episode
    sns.set_style("darkgrid")  # Set a nice style
    plt.figure(figsize=(10, 5))  # Set figure size

    sns.lineplot(x=range(len(total_rewards_list)), y=total_rewards_list, label="Total Reward per Episode")
    sns.lineplot(x=range(len(mean_rewards_list)), y=mean_rewards_list, label="Mean Reward (50 episodes)")

    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.title("Training Progress: Rewards per Episode")
    plt.legend()
    plt.show()

def print_training_parameters(learning_rate, gamma, num_episodes, TAU, SEED):
    print(f"\n")
    print(f"=====================================================================================================")
    print(f"==================================== Training Parameters ===========================================")
    print(f"=====================================================================================================")
    print(f"Number of Episodes: {num_episodes	}")
    print(f"TAU: {TAU}")
    print(f"Learning rate: {learning_rate}")
    print(f"Gamma: {gamma}")
    print(f"Seed: {SEED}")
    print(f"=====================================================================================================")
    print(f"\n")




# Making the RL_model
def train_Agent():
  

    
    print_training_parameters(learning_rate=learning_rate, num_episodes=num_episodes,gamma=gamma, TAU=TAU, SEED=SEED)
    mean_rewards_list = []
    total_rewards_list = []
    best_mean_reward = -np.inf
    total_rewards = 0

    
    #Make the agent
    agent = SACAgent(state_size=space_dim, action_size=action_dim)


    mean_rewards_list = []
    total_rewards_list = []
    best_actions_list = []
    best_states_list = []
    best_episode_rewards_list = []
    best_soc_list = []
    best_mean_reward = -np.inf
    global done_flag
    done_flag = False

    for i_episode in range(num_episodes):
        state = env.reset()
        actions_list = []
        states_list = []
        episode_rewards_list = []
        soc_list = []
        reward_list = []


        done = False
        episode_rewards = 0
        iter = 0
        #print(f"\n  ---- Episode {i_episode} ----:")

        while not done:
            states_list.append(state)
            #print(f"State: {state}")
            action = agent.choose_action(state=state)
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done)

            state = next_state

            episode_rewards += reward
            iter +=1
      
            episode_rewards_list.append(episode_rewards)
   
            
    
            if done:
                #print(f"Starting information Episode {iter}: Starting balance: {self.env.balance}, Starting Stocks: {self.env.stocks_owned} Total_rewards: {episode_rewards} \n")
                break


        total_rewards_list.append(episode_rewards)
        mean_rewards = np.mean(total_rewards_list[-50:] if len(total_rewards_list) >= 50 else 1)
        mean_rewards_list.append(mean_rewards)

        if i_episode % 200 == 0:
            print(f" Episode: {i_episode}, Total Reward: {episode_rewards}, Mean Reward: {mean_rewards}")
 

        if episode_rewards > best_mean_reward:
            #print(f"Updating at Episode: {i_episode}, Total Reward: {mean_rewards}")
            best_mean_reward = episode_rewards

            
    

    plot_training(mean_rewards_list, total_rewards_list)
# Out:
# Space_dim: 8, Action_dim: 4

# %%
train_Agent()
# Out:
# =====================================================================================================
# ==================================== Training Parameters ===========================================
# =====================================================================================================
# Number of Episodes: 1500
# TAU: 0.01
# Learning rate: 0.0001
# Gamma: 0.99
# Seed: 42
# =====================================================================================================
#
#
#  Episode: 0, Total Reward: -340.4082926025041, Mean Reward: 1.0
#  Episode: 200, Total Reward: -70.78499595543812, Mean Reward: -87.07433800734938
#  Episode: 400, Total Reward: 108.1741141266011, Mean Reward: -43.970922308975595
#  Episode: 600, Total Reward: 134.43219710226396, Mean Reward: -1.8728489400923058
#  Episode: 800, Total Reward: 127.8602747400069, Mean Reward: 128.75481804143547
#  Episode: 1000, Total Reward: 180.2045330921597, Mean Reward: 176.23913521884776
#  Episode: 1200, Total Reward: 217.85904265179693, Mean Reward: 189.66990030533546
#  Episode: 1400, Total Reward: 244.64272552013762, Mean Reward: 216.91187657936985

# %%
import numpy as np
import torch



import torch


class Network(torch.nn.Module):

    def __init__(self, input_dimension, output_dimension, output_activation=torch.nn.Identity()):
        super(Network, self).__init__()
        self.layer_1 = torch.nn.Linear(in_features=input_dimension, out_features=64)
        self.layer_2 = torch.nn.Linear(in_features=64, out_features=64)
        self.output_layer = torch.nn.Linear(in_features=64, out_features=output_dimension)
        self.output_activation = output_activation

    def forward(self, inpt):
        layer_1_output = torch.nn.functional.relu(self.layer_1(inpt))
        layer_2_output = torch.nn.functional.relu(self.layer_2(layer_1_output))
        output = self.output_activation(self.output_layer(layer_2_output))
        return output
    
import numpy as np


class ReplayBuffer:

    def __init__(self, environment, capacity=5000):
        transition_type_str = self.get_transition_type_str(environment)
        self.buffer = np.zeros(capacity, dtype=transition_type_str)
        self.weights = np.zeros(capacity)
        self.head_idx = 0
        self.count = 0
        self.capacity = capacity
        self.max_weight = 10**-2
        self.delta = 10**-4
        self.indices = None

    def get_transition_type_str(self, environment):
        state_dim = environment.observation_space.shape[0]
        state_dim_str = '' if state_dim == () else str(state_dim)
        state_type_str = environment.observation_space.sample().dtype.name
        action_dim = environment.action_space.shape
        action_dim_str = '' if action_dim == () else str(action_dim)
        action_type_str = environment.action_space.sample().__class__.__name__

        # type str for transition = 'state type, action type, reward type, state type'
        transition_type_str = '{0}{1}, {2}{3}, float32, {0}{1}, bool'.format(state_dim_str, state_type_str,
                                                                             action_dim_str, action_type_str)

        return transition_type_str

    def add_transition(self, transition):
        self.buffer[self.head_idx] = transition
        self.weights[self.head_idx] = self.max_weight

        self.head_idx = (self.head_idx + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)

    def sample_minibatch(self, size=100):
        set_weights = self.weights[:self.count] + self.delta
        probabilities = set_weights / sum(set_weights)
        self.indices = np.random.choice(range(self.count), size, p=probabilities, replace=False)
        return self.buffer[self.indices]

    def update_weights(self, prediction_errors):
        max_error = max(prediction_errors)
        self.max_weight = max(self.max_weight, max_error)
        self.weights[self.indices] = prediction_errors

    def get_size(self):
        return self.count


class SACAgent:

    ALPHA_INITIAL = 1.
    REPLAY_BUFFER_BATCH_SIZE = 100
    DISCOUNT_RATE = 0.99
    LEARNING_RATE = 10 ** -4
    SOFT_UPDATE_INTERPOLATION_FACTOR = 0.001

    def __init__(self, environment):
        self.environment = environment
        self.state_dim = self.environment.observation_space.shape[0]
        self.action_dim = self.environment.action_space.n
        self.critic_local = Network(input_dimension=self.state_dim,
                                    output_dimension=self.action_dim)
        self.critic_local2 = Network(input_dimension=self.state_dim,
                                     output_dimension=self.action_dim)
        self.critic_optimiser = torch.optim.Adam(self.critic_local.parameters(), lr=self.LEARNING_RATE)
        self.critic_optimiser2 = torch.optim.Adam(self.critic_local2.parameters(), lr=self.LEARNING_RATE)

        self.critic_target = Network(input_dimension=self.state_dim,
                                     output_dimension=self.action_dim)
        self.critic_target2 = Network(input_dimension=self.state_dim,
                                      output_dimension=self.action_dim)

        self.soft_update_target_networks(tau=1.)

        self.actor_local = Network(
            input_dimension=self.state_dim,
            output_dimension=self.action_dim,
            output_activation=torch.nn.Softmax(dim=1)
        )
        self.actor_optimiser = torch.optim.Adam(self.actor_local.parameters(), lr=self.LEARNING_RATE)

        self.replay_buffer = ReplayBuffer(self.environment)

        self.target_entropy = 0.98 * -np.log(1 / self.environment.action_space.n)
        self.log_alpha = torch.tensor(np.log(self.ALPHA_INITIAL), requires_grad=True)
        self.alpha = self.log_alpha
        self.alpha_optimiser = torch.optim.Adam([self.log_alpha], lr=self.LEARNING_RATE)

    def get_next_action(self, state, evaluation_episode=False):
        if evaluation_episode:
            discrete_action = self.get_action_deterministically(state)
        else:
            discrete_action = self.get_action_nondeterministically(state)
        return discrete_action

    def get_action_nondeterministically(self, state):
        action_probabilities = self.get_action_probabilities(state)
        discrete_action = np.random.choice(range(self.action_dim), p=action_probabilities)
        return discrete_action

    def get_action_deterministically(self, state):
        action_probabilities = self.get_action_probabilities(state)
        discrete_action = np.argmax(action_probabilities)
        return discrete_action


    def train_on_transition(self, state, discrete_action, next_state, reward, done):
        transition = (state, discrete_action, reward, next_state, done)
        self.train_networks(transition)

    def train_networks(self, transition):
        # Set all the gradients stored in the optimisers to zero.
        self.critic_optimiser.zero_grad()
        self.critic_optimiser2.zero_grad()
        self.actor_optimiser.zero_grad()
        self.alpha_optimiser.zero_grad()
        # Calculate the loss for this transition.
        self.replay_buffer.add_transition(transition)
        # Compute the gradients based on this loss, i.e. the gradients of the loss with respect to the Q-network
        # parameters.
        if self.replay_buffer.get_size() >= self.REPLAY_BUFFER_BATCH_SIZE:
            # get minibatch of 100 transitions from replay buffer
            minibatch = self.replay_buffer.sample_minibatch(self.REPLAY_BUFFER_BATCH_SIZE)
            minibatch_separated = list(map(list, zip(*minibatch)))

            # unravel transitions to get states, actions, rewards and next states
            states_tensor = torch.tensor(np.array(minibatch_separated[0]))
            actions_tensor = torch.tensor(np.array(minibatch_separated[1]))
            rewards_tensor = torch.tensor(np.array(minibatch_separated[2])).float()
            next_states_tensor = torch.tensor(np.array(minibatch_separated[3]))
            done_tensor = torch.tensor(np.array(minibatch_separated[4]))

            critic_loss, critic2_loss = \
                self.critic_loss(states_tensor, actions_tensor, rewards_tensor, next_states_tensor, done_tensor)

            critic_loss.backward()
            critic2_loss.backward()
            self.critic_optimiser.step()
            self.critic_optimiser2.step()

            actor_loss, log_action_probabilities = self.actor_loss(states_tensor)

            actor_loss.backward()
            self.actor_optimiser.step()

            alpha_loss = self.temperature_loss(log_action_probabilities)

            alpha_loss.backward()
            self.alpha_optimiser.step()
            self.alpha = self.log_alpha.exp()

            self.soft_update_target_networks()

    def critic_loss(self, states_tensor, actions_tensor, rewards_tensor, next_states_tensor, done_tensor):
        actions_tensor = actions_tensor.long()  # Ensure actions_tensor is an integer type
        with torch.no_grad():
            action_probabilities, log_action_probabilities = self.get_action_info(next_states_tensor)
            next_q_values_target = self.critic_target.forward(next_states_tensor)
            next_q_values_target2 = self.critic_target2.forward(next_states_tensor)
            soft_state_values = (action_probabilities * (
                    torch.min(next_q_values_target, next_q_values_target2) - self.alpha * log_action_probabilities
            )).sum(dim=1)

            next_q_values = rewards_tensor + ~done_tensor * self.DISCOUNT_RATE*soft_state_values
        #print(f"next_q_values: {next_q_values.shape}")
        soft_q_values = self.critic_local(states_tensor).gather(1, actions_tensor.unsqueeze(-1)).squeeze(-1)
        soft_q_values2 = self.critic_local2(states_tensor).gather(1, actions_tensor.unsqueeze(-1)).squeeze(-1)
        critic_square_error = torch.nn.MSELoss(reduction="none")(soft_q_values, next_q_values)
        critic2_square_error = torch.nn.MSELoss(reduction="none")(soft_q_values2, next_q_values)
        weight_update = [min(l1.item(), l2.item()) for l1, l2 in zip(critic_square_error, critic2_square_error)]
        self.replay_buffer.update_weights(weight_update)
        critic_loss = critic_square_error.mean()
        critic2_loss = critic2_square_error.mean()
        return critic_loss, critic2_loss

    def actor_loss(self, states_tensor,):
        action_probabilities, log_action_probabilities = self.get_action_info(states_tensor)
        q_values_local = self.critic_local(states_tensor)
        q_values_local2 = self.critic_local2(states_tensor)
        inside_term = self.alpha * log_action_probabilities - torch.min(q_values_local, q_values_local2)
        policy_loss = (action_probabilities * inside_term).sum(dim=1).mean()
        return policy_loss, log_action_probabilities

    def temperature_loss(self, log_action_probabilities):
        alpha_loss = -(self.log_alpha * (log_action_probabilities + self.target_entropy).detach()).mean()
        return alpha_loss

    def get_action_info(self, states_tensor):
        action_probabilities = self.actor_local.forward(states_tensor)
        z = action_probabilities == 0.0
        z = z.float() * 1e-8
        log_action_probabilities = torch.log(action_probabilities + z)
        return action_probabilities, log_action_probabilities

    def get_action_probabilities(self, state):
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
        action_probabilities = self.actor_local.forward(state_tensor)
        return action_probabilities.squeeze(0).detach().numpy()

    def soft_update_target_networks(self, tau=SOFT_UPDATE_INTERPOLATION_FACTOR):
        self.soft_update(self.critic_target, self.critic_local, tau)
        self.soft_update(self.critic_target2, self.critic_local2, tau)

    def soft_update(self, target_model, origin_model, tau):
        for target_param, local_param in zip(target_model.parameters(), origin_model.parameters()):
            target_param.data.copy_(tau * local_param.data + (1 - tau) * target_param.data)

    def predict_q_values(self, state):
        q_values = self.critic_local(state)
        q_values2 = self.critic_local2(state)
        return torch.min(q_values, q_values2)
    

import gym
import numpy as np
import matplotlib.pyplot as plt



TRAINING_EVALUATION_RATIO = 4
RUNS = 5
EPISODES_PER_RUN = 400
STEPS_PER_EPISODE = 500

env = gym.make("CartPole-v1")
agent_results = []
for run in range(RUNS):
    agent = SACAgent(env)
    run_results = []
    for episode_number in range(EPISODES_PER_RUN):
        print('\r', f'Run: {run + 1}/{RUNS} | Episode: {episode_number + 1}/{EPISODES_PER_RUN}', end=' ')
        evaluation_episode = episode_number % TRAINING_EVALUATION_RATIO == 0
        episode_reward = 0
        state = env.reset()
        done = False
        i = 0
        while not done and i < STEPS_PER_EPISODE:
            i += 1
            action = agent.get_next_action(state, evaluation_episode=evaluation_episode)
            next_state, reward, done, info = env.step(action)
            if not evaluation_episode:
                agent.train_on_transition(state, action, next_state, reward, done)
            episode_reward += reward
            state = next_state
        if evaluation_episode:
            run_results.append(episode_reward)
        print(f"Episode: {episode_number}, Reward: {episode_reward}")
    agent_results.append(run_results)

env.close()

n_results = EPISODES_PER_RUN // TRAINING_EVALUATION_RATIO
results_mean = [np.mean([agent_result[n] for agent_result in agent_results]) for n in range(n_results)]
results_std = [np.std([agent_result[n] for agent_result in agent_results]) for n in range(n_results)]
mean_plus_std = [m + s for m, s in zip(results_mean, results_std)]
mean_minus_std = [m - s for m, s in zip(results_mean, results_std)]

x_vals = list(range(len(results_mean)))
x_vals = [x_val * (TRAINING_EVALUATION_RATIO - 1) for x_val in x_vals]

ax = plt.gca()
ax.set_ylim([0, 200])
ax.set_ylabel('Episode Score')
ax.set_xlabel('Training Episode')
ax.plot(x_vals, results_mean, label='Average Result', color='blue')
ax.plot(x_vals, mean_plus_std, color='blue', alpha=0.1)
ax.plot(x_vals, mean_minus_std, color='blue', alpha=0.1)
ax.fill_between(x_vals, y1=mean_minus_std, y2=mean_plus_std, alpha=0.1, color='blue')
plt.legend(loc='best')
plt.show()
# Out:
#  Run: 1/5 | Episode: 1/400 Episode: 0, Reward: 9.0
#  Run: 1/5 | Episode: 2/400 Episode: 1, Reward: 20.0
#  Run: 1/5 | Episode: 3/400 Episode: 2, Reward: 18.0
#  Run: 1/5 | Episode: 4/400 Episode: 3, Reward: 29.0
#  Run: 1/5 | Episode: 5/400 Episode: 4, Reward: 10.0
#  Run: 1/5 | Episode: 6/400 Episode: 5, Reward: 29.0
#  Run: 1/5 | Episode: 7/400 Episode: 6, Reward: 20.0
#  Run: 1/5 | Episode: 8/400 Episode: 7, Reward: 36.0
#  Run: 1/5 | Episode: 9/400 Episode: 8, Reward: 9.0
#  Run: 1/5 | Episode: 10/400 Episode: 9, Reward: 40.0
#  Run: 1/5 | Episode: 11/400 Episode: 10, Reward: 20.0
#  Run: 1/5 | Episode: 12/400 Episode: 11, Reward: 10.0
#  Run: 1/5 | Episode: 13/400 Episode: 12, Reward: 31.0
#  Run: 1/5 | Episode: 14/400 Episode: 13, Reward: 19.0
#  Run: 1/5 | Episode: 15/400 Episode: 14, Reward: 8.0
#  Run: 1/5 | Episode: 16/400 Episode: 15, Reward: 12.0
#  Run: 1/5 | Episode: 17/400 Episode: 16, Reward: 10.0
#  Run: 1/5 | Episode: 18/400 Episode: 17, Reward: 9.0
#  Run: 1/5 | Episode: 19/400 Episode: 18, Reward: 17.0
#  Run: 1/5 | Episode: 20/400 Episode: 19, Reward: 17.0
#  Run: 1/5 | Episode: 21/400 Episode: 20, Reward: 9.0
#  Run: 1/5 | Episode: 22/400 Episode: 21, Reward: 35.0
#  Run: 1/5 | Episode: 23/400 Episode: 22, Reward: 49.0
#  Run: 1/5 | Episode: 24/400 Episode: 23, Reward: 12.0
#  Run: 1/5 | Episode: 25/400 Episode: 24, Reward: 10.0
#  Run: 1/5 | Episode: 26/400 Episode: 25, Reward: 23.0
#  Run: 1/5 | Episode: 27/400 Episode: 26, Reward: 19.0
#  Run: 1/5 | Episode: 28/400 Episode: 27, Reward: 13.0
#  Run: 1/5 | Episode: 29/400 Episode: 28, Reward: 9.0
#  Run: 1/5 | Episode: 30/400 Episode: 29, Reward: 12.0
#  Run: 1/5 | Episode: 31/400 Episode: 30, Reward: 18.0
#  Run: 1/5 | Episode: 32/400 Episode: 31, Reward: 36.0
#  Run: 1/5 | Episode: 33/400 Episode: 32, Reward: 8.0
#  Run: 1/5 | Episode: 34/400 Episode: 33, Reward: 40.0
#  Run: 1/5 | Episode: 35/400 Episode: 34, Reward: 21.0
#  Run: 1/5 | Episode: 36/400 Episode: 35, Reward: 22.0
#  Run: 1/5 | Episode: 37/400 Episode: 36, Reward: 13.0
#  Run: 1/5 | Episode: 38/400 Episode: 37, Reward: 19.0
#  Run: 1/5 | Episode: 39/400 Episode: 38, Reward: 14.0
#  Run: 1/5 | Episode: 40/400 Episode: 39, Reward: 47.0
#  Run: 1/5 | Episode: 41/400 Episode: 40, Reward: 9.0
#  Run: 1/5 | Episode: 42/400 Episode: 41, Reward: 11.0
#  Run: 1/5 | Episode: 43/400 Episode: 42, Reward: 21.0
#  Run: 1/5 | Episode: 44/400 Episode: 43, Reward: 20.0
#  Run: 1/5 | Episode: 45/400 Episode: 44, Reward: 11.0
#  Run: 1/5 | Episode: 46/400 Episode: 45, Reward: 11.0
#  Run: 1/5 | Episode: 47/400 Episode: 46, Reward: 52.0
#  Run: 1/5 | Episode: 48/400 Episode: 47, Reward: 23.0
#  Run: 1/5 | Episode: 49/400 Episode: 48, Reward: 8.0
#  Run: 1/5 | Episode: 50/400 Episode: 49, Reward: 24.0
#  Run: 1/5 | Episode: 51/400 Episode: 50, Reward: 29.0
#  Run: 1/5 | Episode: 52/400 Episode: 51, Reward: 21.0
#  Run: 1/5 | Episode: 53/400 Episode: 52, Reward: 8.0
#  Run: 1/5 | Episode: 54/400 Episode: 53, Reward: 21.0
#  Run: 1/5 | Episode: 55/400 Episode: 54, Reward: 16.0
#  Run: 1/5 | Episode: 56/400 Episode: 55, Reward: 12.0
#  Run: 1/5 | Episode: 57/400 Episode: 56, Reward: 8.0
#  Run: 1/5 | Episode: 58/400 Episode: 57, Reward: 11.0
#  Run: 1/5 | Episode: 59/400 Episode: 58, Reward: 19.0
#  Run: 1/5 | Episode: 60/400 Episode: 59, Reward: 19.0
#  Run: 1/5 | Episode: 61/400 Episode: 60, Reward: 9.0
#  Run: 1/5 | Episode: 62/400 Episode: 61, Reward: 32.0
#  Run: 1/5 | Episode: 63/400 Episode: 62, Reward: 20.0
#  Run: 1/5 | Episode: 64/400 Episode: 63, Reward: 27.0
#  Run: 1/5 | Episode: 65/400 Episode: 64, Reward: 9.0
#  Run: 1/5 | Episode: 66/400 Episode: 65, Reward: 20.0
#  Run: 1/5 | Episode: 67/400 Episode: 66, Reward: 14.0
#  Run: 1/5 | Episode: 68/400 Episode: 67, Reward: 24.0
#  Run: 1/5 | Episode: 69/400 Episode: 68, Reward: 9.0
#  Run: 1/5 | Episode: 70/400 Episode: 69, Reward: 15.0
#  Run: 1/5 | Episode: 71/400 Episode: 70, Reward: 25.0
#  Run: 1/5 | Episode: 72/400 Episode: 71, Reward: 23.0
#  Run: 1/5 | Episode: 73/400 Episode: 72, Reward: 9.0
#  Run: 1/5 | Episode: 74/400 Episode: 73, Reward: 15.0
#  Run: 1/5 | Episode: 75/400 Episode: 74, Reward: 41.0
#  Run: 1/5 | Episode: 76/400 Episode: 75, Reward: 21.0
#  Run: 1/5 | Episode: 77/400 Episode: 76, Reward: 9.0
#  Run: 1/5 | Episode: 78/400 Episode: 77, Reward: 12.0
#  Run: 1/5 | Episode: 79/400 Episode: 78, Reward: 18.0
#  Run: 1/5 | Episode: 80/400 Episode: 79, Reward: 14.0
#  Run: 1/5 | Episode: 81/400 Episode: 80, Reward: 10.0
#  Run: 1/5 | Episode: 82/400 Episode: 81, Reward: 20.0
#  Run: 1/5 | Episode: 83/400 Episode: 82, Reward: 22.0
#  Run: 1/5 | Episode: 84/400 Episode: 83, Reward: 23.0
#  Run: 1/5 | Episode: 85/400 Episode: 84, Reward: 9.0
#  Run: 1/5 | Episode: 86/400 Episode: 85, Reward: 15.0
#  Run: 1/5 | Episode: 87/400 Episode: 86, Reward: 9.0
#  Run: 1/5 | Episode: 88/400 Episode: 87, Reward: 14.0
#  Run: 1/5 | Episode: 89/400 Episode: 88, Reward: 8.0
#  Run: 1/5 | Episode: 90/400 Episode: 89, Reward: 23.0
#  Run: 1/5 | Episode: 91/400 Episode: 90, Reward: 9.0
#  Run: 1/5 | Episode: 92/400 Episode: 91, Reward: 45.0
#  Run: 1/5 | Episode: 93/400 Episode: 92, Reward: 10.0
#  Run: 1/5 | Episode: 94/400 Episode: 93, Reward: 24.0
#  Run: 1/5 | Episode: 95/400 Episode: 94, Reward: 11.0
#  Run: 1/5 | Episode: 96/400 Episode: 95, Reward: 28.0
#  Run: 1/5 | Episode: 97/400 Episode: 96, Reward: 9.0
#  Run: 1/5 | Episode: 98/400 Episode: 97, Reward: 27.0
#  Run: 1/5 | Episode: 99/400 Episode: 98, Reward: 21.0
#  Run: 1/5 | Episode: 100/400 Episode: 99, Reward: 29.0
#  Run: 1/5 | Episode: 101/400 Episode: 100, Reward: 9.0
#  Run: 1/5 | Episode: 102/400 Episode: 101, Reward: 60.0
#  Run: 1/5 | Episode: 103/400 Episode: 102, Reward: 20.0
#  Run: 1/5 | Episode: 104/400 Episode: 103, Reward: 15.0
#  Run: 1/5 | Episode: 105/400 Episode: 104, Reward: 11.0
#  Run: 1/5 | Episode: 106/400 Episode: 105, Reward: 18.0
#  Run: 1/5 | Episode: 107/400 Episode: 106, Reward: 58.0
#  Run: 1/5 | Episode: 108/400 Episode: 107, Reward: 13.0
#  Run: 1/5 | Episode: 109/400 Episode: 108, Reward: 10.0
#  Run: 1/5 | Episode: 110/400 Episode: 109, Reward: 19.0
#  Run: 1/5 | Episode: 111/400 Episode: 110, Reward: 23.0
#  Run: 1/5 | Episode: 112/400 Episode: 111, Reward: 25.0
#  Run: 1/5 | Episode: 113/400 Episode: 112, Reward: 10.0
#  Run: 1/5 | Episode: 114/400 Episode: 113, Reward: 27.0
#  Run: 1/5 | Episode: 115/400 Episode: 114, Reward: 12.0
#  Run: 1/5 | Episode: 116/400 Episode: 115, Reward: 18.0
#  Run: 1/5 | Episode: 117/400 Episode: 116, Reward: 10.0
#  Run: 1/5 | Episode: 118/400 Episode: 117, Reward: 14.0
#  Run: 1/5 | Episode: 119/400 Episode: 118, Reward: 14.0
#  Run: 1/5 | Episode: 120/400 Episode: 119, Reward: 23.0
#  Run: 1/5 | Episode: 121/400 Episode: 120, Reward: 10.0
#  Run: 1/5 | Episode: 122/400 Episode: 121, Reward: 20.0
#  Run: 1/5 | Episode: 123/400 Episode: 122, Reward: 10.0
#  Run: 1/5 | Episode: 124/400 Episode: 123, Reward: 13.0
#  Run: 1/5 | Episode: 125/400 Episode: 124, Reward: 9.0
#  Run: 1/5 | Episode: 126/400 Episode: 125, Reward: 20.0
#  Run: 1/5 | Episode: 127/400 Episode: 126, Reward: 13.0
#  Run: 1/5 | Episode: 128/400 Episode: 127, Reward: 39.0
#  Run: 1/5 | Episode: 129/400 Episode: 128, Reward: 9.0
#  Run: 1/5 | Episode: 130/400 Episode: 129, Reward: 23.0
#  Run: 1/5 | Episode: 131/400 Episode: 130, Reward: 27.0
#  Run: 1/5 | Episode: 132/400 Episode: 131, Reward: 30.0
#  Run: 1/5 | Episode: 133/400 Episode: 132, Reward: 10.0
#  Run: 1/5 | Episode: 134/400 Episode: 133, Reward: 16.0
#  Run: 1/5 | Episode: 135/400 Episode: 134, Reward: 10.0
#  Run: 1/5 | Episode: 136/400 Episode: 135, Reward: 23.0
#  Run: 1/5 | Episode: 137/400 Episode: 136, Reward: 9.0
#  Run: 1/5 | Episode: 138/400 Episode: 137, Reward: 14.0
#  Run: 1/5 | Episode: 139/400 Episode: 138, Reward: 32.0
#  Run: 1/5 | Episode: 140/400 Episode: 139, Reward: 13.0
#  Run: 1/5 | Episode: 141/400 Episode: 140, Reward: 10.0
#  Run: 1/5 | Episode: 142/400 Episode: 141, Reward: 18.0
#  Run: 1/5 | Episode: 143/400 Episode: 142, Reward: 10.0
#  Run: 1/5 | Episode: 144/400 Episode: 143, Reward: 13.0
#  Run: 1/5 | Episode: 145/400 Episode: 144, Reward: 9.0
#  Run: 1/5 | Episode: 146/400 Episode: 145, Reward: 15.0
#  Run: 1/5 | Episode: 147/400 Episode: 146, Reward: 20.0
#  Run: 1/5 | Episode: 148/400 Episode: 147, Reward: 17.0
#  Run: 1/5 | Episode: 149/400 Episode: 148, Reward: 10.0
#  Run: 1/5 | Episode: 150/400 Episode: 149, Reward: 41.0
#  Run: 1/5 | Episode: 151/400 Episode: 150, Reward: 12.0
#  Run: 1/5 | Episode: 152/400 Episode: 151, Reward: 14.0
#  Run: 1/5 | Episode: 153/400 Episode: 152, Reward: 18.0
#  Run: 1/5 | Episode: 154/400 Episode: 153, Reward: 30.0
#  Run: 1/5 | Episode: 155/400 Episode: 154, Reward: 48.0
#  Run: 1/5 | Episode: 156/400 Episode: 155, Reward: 11.0
#  Run: 1/5 | Episode: 157/400 Episode: 156, Reward: 9.0
#  Run: 1/5 | Episode: 158/400 Episode: 157, Reward: 25.0
#  Run: 1/5 | Episode: 159/400 Episode: 158, Reward: 21.0
#  Run: 1/5 | Episode: 160/400 Episode: 159, Reward: 13.0
#  Run: 1/5 | Episode: 161/400 Episode: 160, Reward: 22.0
#  Run: 1/5 | Episode: 162/400 Episode: 161, Reward: 16.0
#  Run: 1/5 | Episode: 163/400 Episode: 162, Reward: 12.0
#  Run: 1/5 | Episode: 164/400 Episode: 163, Reward: 20.0
#  Run: 1/5 | Episode: 165/400 Episode: 164, Reward: 10.0
#  Run: 1/5 | Episode: 166/400 Episode: 165, Reward: 20.0
#  Run: 1/5 | Episode: 167/400 Episode: 166, Reward: 22.0
#  Run: 1/5 | Episode: 168/400 Episode: 167, Reward: 46.0
#  Run: 1/5 | Episode: 169/400 Episode: 168, Reward: 38.0
#  Run: 1/5 | Episode: 170/400 Episode: 169, Reward: 15.0
#  Run: 1/5 | Episode: 171/400 Episode: 170, Reward: 34.0
#  Run: 1/5 | Episode: 172/400 Episode: 171, Reward: 11.0
#  Run: 1/5 | Episode: 173/400 Episode: 172, Reward: 38.0
#  Run: 1/5 | Episode: 174/400 Episode: 173, Reward: 27.0
#  Run: 1/5 | Episode: 175/400 Episode: 174, Reward: 19.0
#  Run: 1/5 | Episode: 176/400 Episode: 175, Reward: 10.0
#  Run: 1/5 | Episode: 177/400 Episode: 176, Reward: 10.0
#  Run: 1/5 | Episode: 178/400 Episode: 177, Reward: 45.0
#  Run: 1/5 | Episode: 179/400 Episode: 178, Reward: 50.0
#  Run: 1/5 | Episode: 180/400 Episode: 179, Reward: 36.0
#  Run: 1/5 | Episode: 181/400 Episode: 180, Reward: 38.0
#  Run: 1/5 | Episode: 182/400 Episode: 181, Reward: 17.0
#  Run: 1/5 | Episode: 183/400 Episode: 182, Reward: 14.0
#  Run: 1/5 | Episode: 184/400 Episode: 183, Reward: 24.0
#  Run: 1/5 | Episode: 185/400 Episode: 184, Reward: 241.0
#  Run: 1/5 | Episode: 186/400 Episode: 185, Reward: 15.0
#  Run: 1/5 | Episode: 187/400 Episode: 186, Reward: 29.0
#  Run: 1/5 | Episode: 188/400 Episode: 187, Reward: 18.0
#  Run: 1/5 | Episode: 189/400 Episode: 188, Reward: 181.0
#  Run: 1/5 | Episode: 190/400 Episode: 189, Reward: 57.0
#  Run: 1/5 | Episode: 191/400 Episode: 190, Reward: 29.0
#  Run: 1/5 | Episode: 192/400 Episode: 191, Reward: 11.0
#  Run: 1/5 | Episode: 193/400 Episode: 192, Reward: 227.0
#  Run: 1/5 | Episode: 194/400 Episode: 193, Reward: 22.0
#  Run: 1/5 | Episode: 195/400 Episode: 194, Reward: 16.0
#  Run: 1/5 | Episode: 196/400 Episode: 195, Reward: 46.0
#  Run: 1/5 | Episode: 197/400 Episode: 196, Reward: 191.0
#  Run: 1/5 | Episode: 198/400 Episode: 197, Reward: 62.0
#  Run: 1/5 | Episode: 199/400 Episode: 198, Reward: 19.0
#  Run: 1/5 | Episode: 200/400 Episode: 199, Reward: 22.0
#  Run: 1/5 | Episode: 201/400 Episode: 200, Reward: 165.0
#  Run: 1/5 | Episode: 202/400 Episode: 201, Reward: 16.0
#  Run: 1/5 | Episode: 203/400 Episode: 202, Reward: 10.0
#  Run: 1/5 | Episode: 204/400 Episode: 203, Reward: 41.0
#  Run: 1/5 | Episode: 205/400 Episode: 204, Reward: 181.0
#  Run: 1/5 | Episode: 206/400 Episode: 205, Reward: 35.0
#  Run: 1/5 | Episode: 207/400 Episode: 206, Reward: 38.0
#  Run: 1/5 | Episode: 208/400 Episode: 207, Reward: 21.0
#  Run: 1/5 | Episode: 209/400 Episode: 208, Reward: 224.0
#  Run: 1/5 | Episode: 210/400 Episode: 209, Reward: 54.0
#  Run: 1/5 | Episode: 211/400 Episode: 210, Reward: 15.0
#  Run: 1/5 | Episode: 212/400 Episode: 211, Reward: 43.0
#  Run: 1/5 | Episode: 213/400 Episode: 212, Reward: 116.0
#  Run: 1/5 | Episode: 214/400 Episode: 213, Reward: 10.0
#  Run: 1/5 | Episode: 215/400 Episode: 214, Reward: 16.0
#  Run: 1/5 | Episode: 216/400 Episode: 215, Reward: 43.0
#  Run: 1/5 | Episode: 217/400 Episode: 216, Reward: 303.0
#  Run: 1/5 | Episode: 218/400 Episode: 217, Reward: 13.0
#  Run: 1/5 | Episode: 219/400 Episode: 218, Reward: 13.0
#  Run: 1/5 | Episode: 220/400 Episode: 219, Reward: 43.0
#  Run: 1/5 | Episode: 221/400 Episode: 220, Reward: 186.0
#  Run: 1/5 | Episode: 222/400 Episode: 221, Reward: 14.0
#  Run: 1/5 | Episode: 223/400 Episode: 222, Reward: 22.0
#  Run: 1/5 | Episode: 224/400 Episode: 223, Reward: 23.0
#  Run: 1/5 | Episode: 225/400 Episode: 224, Reward: 72.0
#  Run: 1/5 | Episode: 226/400 Episode: 225, Reward: 16.0
#  Run: 1/5 | Episode: 227/400 Episode: 226, Reward: 10.0
#  Run: 1/5 | Episode: 228/400 Episode: 227, Reward: 15.0
#  Run: 1/5 | Episode: 229/400 Episode: 228, Reward: 244.0
#  Run: 1/5 | Episode: 230/400 Episode: 229, Reward: 45.0
#  Run: 1/5 | Episode: 231/400 Episode: 230, Reward: 16.0
#  Run: 1/5 | Episode: 232/400 Episode: 231, Reward: 14.0
#  Run: 1/5 | Episode: 233/400 Episode: 232, Reward: 32.0
#  Run: 1/5 | Episode: 234/400 Episode: 233, Reward: 54.0
#  Run: 1/5 | Episode: 235/400 Episode: 234, Reward: 21.0
#  Run: 1/5 | Episode: 236/400 Episode: 235, Reward: 27.0
#  Run: 1/5 | Episode: 237/400 Episode: 236, Reward: 67.0
#  Run: 1/5 | Episode: 238/400 Episode: 237, Reward: 22.0
#  Run: 1/5 | Episode: 239/400 Episode: 238, Reward: 17.0
#  Run: 1/5 | Episode: 240/400 Episode: 239, Reward: 41.0
#  Run: 1/5 | Episode: 241/400 Episode: 240, Reward: 112.0
#  Run: 1/5 | Episode: 242/400 Episode: 241, Reward: 27.0
#  Run: 1/5 | Episode: 243/400 Episode: 242, Reward: 22.0
#  Run: 1/5 | Episode: 244/400 Episode: 243, Reward: 14.0
#  Run: 1/5 | Episode: 245/400 Episode: 244, Reward: 153.0
#  Run: 1/5 | Episode: 246/400 Episode: 245, Reward: 23.0
#  Run: 1/5 | Episode: 247/400 Episode: 246, Reward: 25.0
#  Run: 1/5 | Episode: 248/400 Episode: 247, Reward: 21.0
#  Run: 1/5 | Episode: 249/400 Episode: 248, Reward: 327.0
#  Run: 1/5 | Episode: 250/400 Episode: 249, Reward: 37.0
#  Run: 1/5 | Episode: 251/400 Episode: 250, Reward: 25.0
#  Run: 1/5 | Episode: 252/400 Episode: 251, Reward: 32.0
#  Run: 1/5 | Episode: 253/400 Episode: 252, Reward: 243.0
#  Run: 1/5 | Episode: 254/400 Episode: 253, Reward: 19.0
#  Run: 1/5 | Episode: 255/400 Episode: 254, Reward: 14.0
#  Run: 1/5 | Episode: 256/400 Episode: 255, Reward: 88.0
#  Run: 1/5 | Episode: 257/400 Episode: 256, Reward: 52.0
#  Run: 1/5 | Episode: 258/400 Episode: 257, Reward: 27.0
#  Run: 1/5 | Episode: 259/400 Episode: 258, Reward: 9.0
#  Run: 1/5 | Episode: 260/400 Episode: 259, Reward: 21.0
#  Run: 1/5 | Episode: 261/400 Episode: 260, Reward: 232.0
#  Run: 1/5 | Episode: 262/400 Episode: 261, Reward: 24.0
#  Run: 1/5 | Episode: 263/400 Episode: 262, Reward: 18.0
#  Run: 1/5 | Episode: 264/400 Episode: 263, Reward: 16.0
#  Run: 1/5 | Episode: 265/400 Episode: 264, Reward: 217.0
#  Run: 1/5 | Episode: 266/400 Episode: 265, Reward: 15.0
#  Run: 1/5 | Episode: 267/400 Episode: 266, Reward: 15.0
#  Run: 1/5 | Episode: 268/400 Episode: 267, Reward: 22.0
#  Run: 1/5 | Episode: 269/400 Episode: 268, Reward: 227.0
#  Run: 1/5 | Episode: 270/400 Episode: 269, Reward: 29.0
#  Run: 1/5 | Episode: 271/400 Episode: 270, Reward: 31.0
#  Run: 1/5 | Episode: 272/400 Episode: 271, Reward: 22.0
#  Run: 1/5 | Episode: 273/400 Episode: 272, Reward: 183.0
#  Run: 1/5 | Episode: 274/400 Episode: 273, Reward: 43.0
#  Run: 1/5 | Episode: 275/400 Episode: 274, Reward: 23.0
#  Run: 1/5 | Episode: 276/400 Episode: 275, Reward: 13.0
#  Run: 1/5 | Episode: 277/400 Episode: 276, Reward: 217.0
#  Run: 1/5 | Episode: 278/400 Episode: 277, Reward: 28.0
#  Run: 1/5 | Episode: 279/400 Episode: 278, Reward: 49.0
#  Run: 1/5 | Episode: 280/400 Episode: 279, Reward: 14.0
#  Run: 1/5 | Episode: 281/400 Episode: 280, Reward: 181.0
#  Run: 1/5 | Episode: 282/400 Episode: 281, Reward: 37.0
#  Run: 1/5 | Episode: 283/400 Episode: 282, Reward: 15.0
#  Run: 1/5 | Episode: 284/400 Episode: 283, Reward: 19.0
#  Run: 1/5 | Episode: 285/400 Episode: 284, Reward: 194.0
#  Run: 1/5 | Episode: 286/400 Episode: 285, Reward: 19.0
#  Run: 1/5 | Episode: 287/400 Episode: 286, Reward: 53.0
#  Run: 1/5 | Episode: 288/400 Episode: 287, Reward: 16.0
#  Run: 1/5 | Episode: 289/400 Episode: 288, Reward: 193.0
#  Run: 1/5 | Episode: 290/400 Episode: 289, Reward: 14.0
#  Run: 1/5 | Episode: 291/400 Episode: 290, Reward: 17.0
#  Run: 1/5 | Episode: 292/400 Episode: 291, Reward: 39.0
#  Run: 1/5 | Episode: 293/400 Episode: 292, Reward: 175.0
#  Run: 1/5 | Episode: 294/400 Episode: 293, Reward: 14.0
#  Run: 1/5 | Episode: 295/400 Episode: 294, Reward: 16.0
#  Run: 1/5 | Episode: 296/400 Episode: 295, Reward: 17.0
#  Run: 1/5 | Episode: 297/400 Episode: 296, Reward: 170.0
#  Run: 1/5 | Episode: 298/400 Episode: 297, Reward: 13.0
#  Run: 1/5 | Episode: 299/400 Episode: 298, Reward: 29.0
#  Run: 1/5 | Episode: 300/400 Episode: 299, Reward: 51.0
#  Run: 1/5 | Episode: 301/400 Episode: 300, Reward: 161.0
#  Run: 1/5 | Episode: 302/400 Episode: 301, Reward: 15.0
#  Run: 1/5 | Episode: 303/400 Episode: 302, Reward: 13.0
#  Run: 1/5 | Episode: 304/400 Episode: 303, Reward: 21.0
#  Run: 1/5 | Episode: 305/400 Episode: 304, Reward: 148.0
#  Run: 1/5 | Episode: 306/400 Episode: 305, Reward: 41.0
#  Run: 1/5 | Episode: 307/400 Episode: 306, Reward: 20.0
#  Run: 1/5 | Episode: 308/400 Episode: 307, Reward: 63.0
#  Run: 1/5 | Episode: 309/400 Episode: 308, Reward: 160.0
#  Run: 1/5 | Episode: 310/400 Episode: 309, Reward: 17.0
#  Run: 1/5 | Episode: 311/400 Episode: 310, Reward: 29.0
#  Run: 1/5 | Episode: 312/400 Episode: 311, Reward: 26.0
#  Run: 1/5 | Episode: 313/400 Episode: 312, Reward: 156.0
#  Run: 1/5 | Episode: 314/400 Episode: 313, Reward: 54.0
#  Run: 1/5 | Episode: 315/400 Episode: 314, Reward: 51.0
#  Run: 1/5 | Episode: 316/400 Episode: 315, Reward: 11.0
#  Run: 1/5 | Episode: 317/400 Episode: 316, Reward: 153.0
#  Run: 1/5 | Episode: 318/400 Episode: 317, Reward: 29.0
#  Run: 1/5 | Episode: 319/400 Episode: 318, Reward: 91.0
#  Run: 1/5 | Episode: 320/400 Episode: 319, Reward: 17.0
#  Run: 1/5 | Episode: 321/400 Episode: 320, Reward: 140.0
#  Run: 1/5 | Episode: 322/400 Episode: 321, Reward: 26.0
#  Run: 1/5 | Episode: 323/400 Episode: 322, Reward: 10.0
#  Run: 1/5 | Episode: 324/400 Episode: 323, Reward: 51.0
#  Run: 1/5 | Episode: 325/400 Episode: 324, Reward: 113.0
#  Run: 1/5 | Episode: 326/400 Episode: 325, Reward: 28.0
#  Run: 1/5 | Episode: 327/400 Episode: 326, Reward: 15.0
#  Run: 1/5 | Episode: 328/400 Episode: 327, Reward: 59.0
#  Run: 1/5 | Episode: 329/400 Episode: 328, Reward: 108.0
#  Run: 1/5 | Episode: 330/400 Episode: 329, Reward: 12.0
#  Run: 1/5 | Episode: 331/400 Episode: 330, Reward: 25.0
#  Run: 1/5 | Episode: 332/400 Episode: 331, Reward: 69.0
#  Run: 1/5 | Episode: 333/400 Episode: 332, Reward: 99.0
#  Run: 1/5 | Episode: 334/400 Episode: 333, Reward: 48.0
#  Run: 1/5 | Episode: 335/400 Episode: 334, Reward: 17.0
#  Run: 1/5 | Episode: 336/400 Episode: 335, Reward: 21.0
#  Run: 1/5 | Episode: 337/400 Episode: 336, Reward: 106.0
#  Run: 1/5 | Episode: 338/400 Episode: 337, Reward: 19.0
#  Run: 1/5 | Episode: 339/400 Episode: 338, Reward: 53.0
#  Run: 1/5 | Episode: 340/400 Episode: 339, Reward: 15.0
#  Run: 1/5 | Episode: 341/400 Episode: 340, Reward: 129.0
#  Run: 1/5 | Episode: 342/400 Episode: 341, Reward: 63.0
#  Run: 1/5 | Episode: 343/400 Episode: 342, Reward: 51.0
#  Run: 1/5 | Episode: 344/400 Episode: 343, Reward: 34.0
#  Run: 1/5 | Episode: 345/400 Episode: 344, Reward: 103.0
#  Run: 1/5 | Episode: 346/400 Episode: 345, Reward: 11.0
#  Run: 1/5 | Episode: 347/400 Episode: 346, Reward: 51.0
#  Run: 1/5 | Episode: 348/400 Episode: 347, Reward: 24.0
#  Run: 1/5 | Episode: 349/400 Episode: 348, Reward: 121.0
#  Run: 1/5 | Episode: 350/400 Episode: 349, Reward: 43.0
#  Run: 1/5 | Episode: 351/400 Episode: 350, Reward: 13.0
#  Run: 1/5 | Episode: 352/400 Episode: 351, Reward: 12.0
#  Run: 1/5 | Episode: 353/400 Episode: 352, Reward: 172.0
#  Run: 1/5 | Episode: 354/400 Episode: 353, Reward: 11.0
#  Run: 1/5 | Episode: 355/400 Episode: 354, Reward: 22.0
#  Run: 1/5 | Episode: 356/400 Episode: 355, Reward: 22.0
#  Run: 1/5 | Episode: 357/400 Episode: 356, Reward: 143.0
#  Run: 1/5 | Episode: 358/400 Episode: 357, Reward: 32.0
#  Run: 1/5 | Episode: 359/400 Episode: 358, Reward: 13.0
#  Run: 1/5 | Episode: 360/400 Episode: 359, Reward: 13.0
#  Run: 1/5 | Episode: 361/400 Episode: 360, Reward: 134.0
#  Run: 1/5 | Episode: 362/400 Episode: 361, Reward: 12.0
#  Run: 1/5 | Episode: 363/400 Episode: 362, Reward: 15.0
#  Run: 1/5 | Episode: 364/400 Episode: 363, Reward: 25.0
#  Run: 1/5 | Episode: 365/400 Episode: 364, Reward: 128.0
#  Run: 1/5 | Episode: 366/400 Episode: 365, Reward: 15.0
#  Run: 1/5 | Episode: 367/400 Episode: 366, Reward: 9.0
#  Run: 1/5 | Episode: 368/400 Episode: 367, Reward: 39.0
#  Run: 1/5 | Episode: 369/400 Episode: 368, Reward: 141.0
#  Run: 1/5 | Episode: 370/400 Episode: 369, Reward: 16.0
#  Run: 1/5 | Episode: 371/400 Episode: 370, Reward: 69.0
#  Run: 1/5 | Episode: 372/400 Episode: 371, Reward: 15.0
#  Run: 1/5 | Episode: 373/400 Episode: 372, Reward: 162.0
#  Run: 1/5 | Episode: 374/400 Episode: 373, Reward: 42.0
#  Run: 1/5 | Episode: 375/400 Episode: 374, Reward: 15.0
#  Run: 1/5 | Episode: 376/400 Episode: 375, Reward: 19.0
#  Run: 1/5 | Episode: 377/400 Episode: 376, Reward: 181.0
#  Run: 1/5 | Episode: 378/400 Episode: 377, Reward: 18.0
#  Run: 1/5 | Episode: 379/400 Episode: 378, Reward: 28.0
#  Run: 1/5 | Episode: 380/400 Episode: 379, Reward: 51.0
#  Run: 1/5 | Episode: 381/400 Episode: 380, Reward: 213.0
#  Run: 1/5 | Episode: 382/400 Episode: 381, Reward: 16.0
#  Run: 1/5 | Episode: 383/400 Episode: 382, Reward: 30.0
#  Run: 1/5 | Episode: 384/400 Episode: 383, Reward: 39.0
#  Run: 1/5 | Episode: 385/400 Episode: 384, Reward: 211.0
#  Run: 1/5 | Episode: 386/400 Episode: 385, Reward: 16.0
#  Run: 1/5 | Episode: 387/400 Episode: 386, Reward: 15.0
#  Run: 1/5 | Episode: 388/400 Episode: 387, Reward: 20.0
#  Run: 1/5 | Episode: 389/400 Episode: 388, Reward: 269.0
#  Run: 1/5 | Episode: 390/400 Episode: 389, Reward: 24.0
#  Run: 1/5 | Episode: 391/400 Episode: 390, Reward: 56.0
#  Run: 1/5 | Episode: 392/400 Episode: 391, Reward: 22.0
#  Run: 1/5 | Episode: 393/400 Episode: 392, Reward: 166.0
#  Run: 1/5 | Episode: 394/400 Episode: 393, Reward: 33.0
#  Run: 1/5 | Episode: 395/400 Episode: 394, Reward: 19.0
#  Run: 1/5 | Episode: 396/400 Episode: 395, Reward: 15.0
#  Run: 1/5 | Episode: 397/400 Episode: 396, Reward: 169.0
#  Run: 1/5 | Episode: 398/400 Episode: 397, Reward: 10.0
#  Run: 1/5 | Episode: 399/400 Episode: 398, Reward: 13.0
#  Run: 1/5 | Episode: 400/400 Episode: 399, Reward: 12.0
#  Run: 2/5 | Episode: 1/400 Episode: 0, Reward: 10.0
#  Run: 2/5 | Episode: 2/400 Episode: 1, Reward: 15.0
#  Run: 2/5 | Episode: 3/400 Episode: 2, Reward: 12.0
#  Run: 2/5 | Episode: 4/400 Episode: 3, Reward: 16.0
#  Run: 2/5 | Episode: 5/400 Episode: 4, Reward: 9.0
#  Run: 2/5 | Episode: 6/400 Episode: 5, Reward: 48.0
#  Run: 2/5 | Episode: 7/400 Episode: 6, Reward: 15.0
#  Run: 2/5 | Episode: 8/400 Episode: 7, Reward: 11.0
#  Run: 2/5 | Episode: 9/400 Episode: 8, Reward: 9.0
#  Run: 2/5 | Episode: 10/400 Episode: 9, Reward: 12.0
#  Run: 2/5 | Episode: 11/400 Episode: 10, Reward: 102.0
#  Run: 2/5 | Episode: 12/400 Episode: 11, Reward: 23.0
#  Run: 2/5 | Episode: 13/400 Episode: 12, Reward: 8.0
#  Run: 2/5 | Episode: 14/400 Episode: 13, Reward: 41.0
#  Run: 2/5 | Episode: 15/400 Episode: 14, Reward: 30.0
#  Run: 2/5 | Episode: 16/400 Episode: 15, Reward: 23.0
#  Run: 2/5 | Episode: 17/400 Episode: 16, Reward: 22.0
#  Run: 2/5 | Episode: 18/400 Episode: 17, Reward: 20.0
#  Run: 2/5 | Episode: 19/400 Episode: 18, Reward: 15.0
#  Run: 2/5 | Episode: 20/400 Episode: 19, Reward: 11.0
#  Run: 2/5 | Episode: 21/400 Episode: 20, Reward: 17.0
#  Run: 2/5 | Episode: 22/400 Episode: 21, Reward: 18.0
#  Run: 2/5 | Episode: 23/400 Episode: 22, Reward: 19.0
#  Run: 2/5 | Episode: 24/400 Episode: 23, Reward: 22.0
#  Run: 2/5 | Episode: 25/400 Episode: 24, Reward: 13.0
#  Run: 2/5 | Episode: 26/400 Episode: 25, Reward: 18.0
#  Run: 2/5 | Episode: 27/400 Episode: 26, Reward: 36.0
#  Run: 2/5 | Episode: 28/400 Episode: 27, Reward: 19.0
#  Run: 2/5 | Episode: 29/400 Episode: 28, Reward: 14.0
#  Run: 2/5 | Episode: 30/400 Episode: 29, Reward: 18.0
#  Run: 2/5 | Episode: 31/400 Episode: 30, Reward: 16.0
#  Run: 2/5 | Episode: 32/400 Episode: 31, Reward: 23.0
#  Run: 2/5 | Episode: 33/400 Episode: 32, Reward: 8.0
#  Run: 2/5 | Episode: 34/400 Episode: 33, Reward: 13.0
#  Run: 2/5 | Episode: 35/400 Episode: 34, Reward: 19.0
#  Run: 2/5 | Episode: 36/400 Episode: 35, Reward: 17.0
#  Run: 2/5 | Episode: 37/400 Episode: 36, Reward: 12.0
#  Run: 2/5 | Episode: 38/400 Episode: 37, Reward: 30.0
#  Run: 2/5 | Episode: 39/400 Episode: 38, Reward: 13.0
#  Run: 2/5 | Episode: 40/400 Episode: 39, Reward: 8.0
#  Run: 2/5 | Episode: 41/400 Episode: 40, Reward: 12.0
#  Run: 2/5 | Episode: 42/400 Episode: 41, Reward: 19.0
#  Run: 2/5 | Episode: 43/400 Episode: 42, Reward: 13.0
#  Run: 2/5 | Episode: 44/400 Episode: 43, Reward: 17.0
#  Run: 2/5 | Episode: 45/400 Episode: 44, Reward: 13.0
#  Run: 2/5 | Episode: 46/400 Episode: 45, Reward: 39.0
#  Run: 2/5 | Episode: 47/400 Episode: 46, Reward: 23.0
#  Run: 2/5 | Episode: 48/400 Episode: 47, Reward: 18.0
#  Run: 2/5 | Episode: 49/400 Episode: 48, Reward: 11.0
#  Run: 2/5 | Episode: 50/400 Episode: 49, Reward: 11.0
#  Run: 2/5 | Episode: 51/400 Episode: 50, Reward: 20.0
#  Run: 2/5 | Episode: 52/400 Episode: 51, Reward: 10.0
#  Run: 2/5 | Episode: 53/400 Episode: 52, Reward: 10.0
#  Run: 2/5 | Episode: 54/400 Episode: 53, Reward: 10.0
#  Run: 2/5 | Episode: 55/400 Episode: 54, Reward: 18.0
#  Run: 2/5 | Episode: 56/400 Episode: 55, Reward: 16.0
#  Run: 2/5 | Episode: 57/400 Episode: 56, Reward: 13.0
#  Run: 2/5 | Episode: 58/400 Episode: 57, Reward: 12.0
#  Run: 2/5 | Episode: 59/400 Episode: 58, Reward: 26.0
#  Run: 2/5 | Episode: 60/400 Episode: 59, Reward: 21.0
#  Run: 2/5 | Episode: 61/400 Episode: 60, Reward: 8.0
#  Run: 2/5 | Episode: 62/400 Episode: 61, Reward: 16.0
#  Run: 2/5 | Episode: 63/400 Episode: 62, Reward: 43.0
#  Run: 2/5 | Episode: 64/400 Episode: 63, Reward: 20.0
#  Run: 2/5 | Episode: 65/400 Episode: 64, Reward: 9.0
#  Run: 2/5 | Episode: 66/400 Episode: 65, Reward: 16.0
#  Run: 2/5 | Episode: 67/400 Episode: 66, Reward: 26.0
#  Run: 2/5 | Episode: 68/400 Episode: 67, Reward: 35.0
#  Run: 2/5 | Episode: 69/400 Episode: 68, Reward: 9.0
#  Run: 2/5 | Episode: 70/400 Episode: 69, Reward: 13.0
#  Run: 2/5 | Episode: 71/400 Episode: 70, Reward: 13.0
#  Run: 2/5 | Episode: 72/400 Episode: 71, Reward: 26.0
#  Run: 2/5 | Episode: 73/400 Episode: 72, Reward: 10.0
#  Run: 2/5 | Episode: 74/400 Episode: 73, Reward: 14.0
#  Run: 2/5 | Episode: 75/400 Episode: 74, Reward: 11.0
#  Run: 2/5 | Episode: 76/400 Episode: 75, Reward: 19.0
#  Run: 2/5 | Episode: 77/400 Episode: 76, Reward: 10.0
#  Run: 2/5 | Episode: 78/400 Episode: 77, Reward: 13.0
#  Run: 2/5 | Episode: 79/400 Episode: 78, Reward: 23.0
#  Run: 2/5 | Episode: 80/400 Episode: 79, Reward: 26.0
#  Run: 2/5 | Episode: 81/400 Episode: 80, Reward: 9.0
#  Run: 2/5 | Episode: 82/400 Episode: 81, Reward: 13.0
#  Run: 2/5 | Episode: 83/400 Episode: 82, Reward: 31.0
#  Run: 2/5 | Episode: 84/400 Episode: 83, Reward: 16.0
#  Run: 2/5 | Episode: 85/400 Episode: 84, Reward: 9.0
#  Run: 2/5 | Episode: 86/400 Episode: 85, Reward: 35.0
#  Run: 2/5 | Episode: 87/400 Episode: 86, Reward: 20.0
#  Run: 2/5 | Episode: 88/400 Episode: 87, Reward: 16.0
#  Run: 2/5 | Episode: 89/400 Episode: 88, Reward: 11.0
#  Run: 2/5 | Episode: 90/400 Episode: 89, Reward: 35.0
#  Run: 2/5 | Episode: 91/400 Episode: 90, Reward: 40.0
#  Run: 2/5 | Episode: 92/400 Episode: 91, Reward: 21.0
#  Run: 2/5 | Episode: 93/400 Episode: 92, Reward: 9.0
#  Run: 2/5 | Episode: 94/400 Episode: 93, Reward: 23.0
#  Run: 2/5 | Episode: 95/400 Episode: 94, Reward: 18.0
#  Run: 2/5 | Episode: 96/400 Episode: 95, Reward: 10.0
#  Run: 2/5 | Episode: 97/400 Episode: 96, Reward: 9.0
#  Run: 2/5 | Episode: 98/400 Episode: 97, Reward: 13.0
#  Run: 2/5 | Episode: 99/400 Episode: 98, Reward: 21.0
#  Run: 2/5 | Episode: 100/400 Episode: 99, Reward: 33.0
#  Run: 2/5 | Episode: 101/400 Episode: 100, Reward: 9.0
#  Run: 2/5 | Episode: 102/400 Episode: 101, Reward: 15.0
#  Run: 2/5 | Episode: 103/400 Episode: 102, Reward: 13.0
#  Run: 2/5 | Episode: 104/400 Episode: 103, Reward: 16.0
#  Run: 2/5 | Episode: 105/400 Episode: 104, Reward: 11.0
#  Run: 2/5 | Episode: 106/400 Episode: 105, Reward: 10.0
#  Run: 2/5 | Episode: 107/400 Episode: 106, Reward: 10.0
#  Run: 2/5 | Episode: 108/400 Episode: 107, Reward: 16.0
#  Run: 2/5 | Episode: 109/400 Episode: 108, Reward: 12.0
#  Run: 2/5 | Episode: 110/400 Episode: 109, Reward: 33.0
#  Run: 2/5 | Episode: 111/400 Episode: 110, Reward: 26.0
#  Run: 2/5 | Episode: 112/400 Episode: 111, Reward: 13.0
#  Run: 2/5 | Episode: 113/400 Episode: 112, Reward: 10.0
#  Run: 2/5 | Episode: 114/400 Episode: 113, Reward: 17.0
#  Run: 2/5 | Episode: 115/400 Episode: 114, Reward: 23.0
#  Run: 2/5 | Episode: 116/400 Episode: 115, Reward: 14.0
#  Run: 2/5 | Episode: 117/400 Episode: 116, Reward: 9.0
#  Run: 2/5 | Episode: 118/400 Episode: 117, Reward: 26.0
#  Run: 2/5 | Episode: 119/400 Episode: 118, Reward: 10.0
#  Run: 2/5 | Episode: 120/400 Episode: 119, Reward: 29.0
#  Run: 2/5 | Episode: 121/400 Episode: 120, Reward: 11.0
#  Run: 2/5 | Episode: 122/400 Episode: 121, Reward: 23.0
#  Run: 2/5 | Episode: 123/400 Episode: 122, Reward: 9.0
#  Run: 2/5 | Episode: 124/400 Episode: 123, Reward: 17.0
#  Run: 2/5 | Episode: 125/400 Episode: 124, Reward: 11.0
#  Run: 2/5 | Episode: 126/400 Episode: 125, Reward: 16.0
#  Run: 2/5 | Episode: 127/400 Episode: 126, Reward: 11.0
#  Run: 2/5 | Episode: 128/400 Episode: 127, Reward: 16.0
#  Run: 2/5 | Episode: 129/400 Episode: 128, Reward: 9.0
#  Run: 2/5 | Episode: 130/400 Episode: 129, Reward: 18.0
#  Run: 2/5 | Episode: 131/400 Episode: 130, Reward: 20.0
#  Run: 2/5 | Episode: 132/400 Episode: 131, Reward: 13.0
#  Run: 2/5 | Episode: 133/400 Episode: 132, Reward: 9.0
#  Run: 2/5 | Episode: 134/400 Episode: 133, Reward: 12.0
#  Run: 2/5 | Episode: 135/400 Episode: 134, Reward: 38.0
#  Run: 2/5 | Episode: 136/400 Episode: 135, Reward: 10.0
#  Run: 2/5 | Episode: 137/400 Episode: 136, Reward: 10.0
#  Run: 2/5 | Episode: 138/400 Episode: 137, Reward: 17.0
#  Run: 2/5 | Episode: 139/400 Episode: 138, Reward: 14.0
#  Run: 2/5 | Episode: 140/400 Episode: 139, Reward: 13.0
#  Run: 2/5 | Episode: 141/400 Episode: 140, Reward: 12.0
#  Run: 2/5 | Episode: 142/400 Episode: 141, Reward: 18.0
#  Run: 2/5 | Episode: 143/400 Episode: 142, Reward: 20.0
#  Run: 2/5 | Episode: 144/400 Episode: 143, Reward: 16.0
#  Run: 2/5 | Episode: 145/400 Episode: 144, Reward: 12.0
#  Run: 2/5 | Episode: 146/400 Episode: 145, Reward: 23.0
#  Run: 2/5 | Episode: 147/400 Episode: 146, Reward: 19.0
#  Run: 2/5 | Episode: 148/400 Episode: 147, Reward: 16.0
#  Run: 2/5 | Episode: 149/400 Episode: 148, Reward: 11.0
#  Run: 2/5 | Episode: 150/400 Episode: 149, Reward: 43.0
#  Run: 2/5 | Episode: 151/400 Episode: 150, Reward: 16.0
#  Run: 2/5 | Episode: 152/400 Episode: 151, Reward: 15.0
#  Run: 2/5 | Episode: 153/400 Episode: 152, Reward: 11.0
#  Run: 2/5 | Episode: 154/400 Episode: 153, Reward: 11.0
#  Run: 2/5 | Episode: 155/400 Episode: 154, Reward: 24.0
#  Run: 2/5 | Episode: 156/400 Episode: 155, Reward: 15.0
#  Run: 2/5 | Episode: 157/400 Episode: 156, Reward: 11.0
#  Run: 2/5 | Episode: 158/400 Episode: 157, Reward: 14.0
#  Run: 2/5 | Episode: 159/400 Episode: 158, Reward: 11.0
#  Run: 2/5 | Episode: 160/400 Episode: 159, Reward: 39.0
#  Run: 2/5 | Episode: 161/400 Episode: 160, Reward: 10.0
#  Run: 2/5 | Episode: 162/400 Episode: 161, Reward: 14.0
#  Run: 2/5 | Episode: 163/400 Episode: 162, Reward: 13.0
#  Run: 2/5 | Episode: 164/400 Episode: 163, Reward: 21.0
#  Run: 2/5 | Episode: 165/400 Episode: 164, Reward: 13.0
#  Run: 2/5 | Episode: 166/400 Episode: 165, Reward: 13.0
#  Run: 2/5 | Episode: 167/400 Episode: 166, Reward: 33.0
#  Run: 2/5 | Episode: 168/400 Episode: 167, Reward: 10.0
#  Run: 2/5 | Episode: 169/400 Episode: 168, Reward: 12.0
#  Run: 2/5 | Episode: 170/400 Episode: 169, Reward: 14.0
#  Run: 2/5 | Episode: 171/400 Episode: 170, Reward: 11.0
#  Run: 2/5 | Episode: 172/400 Episode: 171, Reward: 22.0
#  Run: 2/5 | Episode: 173/400 Episode: 172, Reward: 11.0
#  Run: 2/5 | Episode: 174/400 Episode: 173, Reward: 16.0
#  Run: 2/5 | Episode: 175/400 Episode: 174, Reward: 27.0
#  Run: 2/5 | Episode: 176/400 Episode: 175, Reward: 13.0
#  Run: 2/5 | Episode: 177/400 Episode: 176, Reward: 10.0
#  Run: 2/5 | Episode: 178/400 Episode: 177, Reward: 12.0
#  Run: 2/5 | Episode: 179/400 Episode: 178, Reward: 14.0
#  Run: 2/5 | Episode: 180/400 Episode: 179, Reward: 17.0
#  Run: 2/5 | Episode: 181/400 Episode: 180, Reward: 13.0
#  Run: 2/5 | Episode: 182/400 Episode: 181, Reward: 13.0
#  Run: 2/5 | Episode: 183/400 Episode: 182, Reward: 14.0
#  Run: 2/5 | Episode: 184/400 Episode: 183, Reward: 18.0
#  Run: 2/5 | Episode: 185/400 Episode: 184, Reward: 10.0
#  Run: 2/5 | Episode: 186/400 Episode: 185, Reward: 31.0
#  Run: 2/5 | Episode: 187/400 Episode: 186, Reward: 17.0
#  Run: 2/5 | Episode: 188/400 Episode: 187, Reward: 47.0
#  Run: 2/5 | Episode: 189/400 Episode: 188, Reward: 15.0
#  Run: 2/5 | Episode: 190/400 Episode: 189, Reward: 24.0
#  Run: 2/5 | Episode: 191/400 Episode: 190, Reward: 22.0
#  Run: 2/5 | Episode: 192/400 Episode: 191, Reward: 15.0
#  Run: 2/5 | Episode: 193/400 Episode: 192, Reward: 13.0
#  Run: 2/5 | Episode: 194/400 Episode: 193, Reward: 13.0
#  Run: 2/5 | Episode: 195/400 Episode: 194, Reward: 17.0
#  Run: 2/5 | Episode: 196/400 Episode: 195, Reward: 11.0
#  Run: 2/5 | Episode: 197/400 Episode: 196, Reward: 11.0
#  Run: 2/5 | Episode: 198/400 Episode: 197, Reward: 35.0
#  Run: 2/5 | Episode: 199/400 Episode: 198, Reward: 41.0
#  Run: 2/5 | Episode: 200/400 Episode: 199, Reward: 50.0
#  Run: 2/5 | Episode: 201/400 Episode: 200, Reward: 10.0
#  Run: 2/5 | Episode: 202/400 Episode: 201, Reward: 12.0
#  Run: 2/5 | Episode: 203/400 Episode: 202, Reward: 15.0
#  Run: 2/5 | Episode: 204/400 Episode: 203, Reward: 14.0
#  Run: 2/5 | Episode: 205/400 Episode: 204, Reward: 11.0
#  Run: 2/5 | Episode: 206/400 Episode: 205, Reward: 13.0
#  Run: 2/5 | Episode: 207/400 Episode: 206, Reward: 31.0
#  Run: 2/5 | Episode: 208/400 Episode: 207, Reward: 18.0
#  Run: 2/5 | Episode: 209/400 Episode: 208, Reward: 14.0
#  Run: 2/5 | Episode: 210/400 Episode: 209, Reward: 15.0
#  Run: 2/5 | Episode: 211/400 Episode: 210, Reward: 17.0
#  Run: 2/5 | Episode: 212/400 Episode: 211, Reward: 91.0
#  Run: 2/5 | Episode: 213/400 Episode: 212, Reward: 15.0
#  Run: 2/5 | Episode: 214/400 Episode: 213, Reward: 28.0
#  Run: 2/5 | Episode: 215/400 Episode: 214, Reward: 16.0
#  Run: 2/5 | Episode: 216/400 Episode: 215, Reward: 17.0
#  Run: 2/5 | Episode: 217/400 Episode: 216, Reward: 16.0
#  Run: 2/5 | Episode: 218/400 Episode: 217, Reward: 20.0
#  Run: 2/5 | Episode: 219/400 Episode: 218, Reward: 15.0
#  Run: 2/5 | Episode: 220/400 Episode: 219, Reward: 29.0
#  Run: 2/5 | Episode: 221/400 Episode: 220, Reward: 16.0
#  Run: 2/5 | Episode: 222/400 Episode: 221, Reward: 19.0
#  Run: 2/5 | Episode: 223/400 Episode: 222, Reward: 14.0
#  Run: 2/5 | Episode: 224/400 Episode: 223, Reward: 12.0
#  Run: 2/5 | Episode: 225/400 Episode: 224, Reward: 13.0
#  Run: 2/5 | Episode: 226/400 Episode: 225, Reward: 12.0
#  Run: 2/5 | Episode: 227/400 Episode: 226, Reward: 28.0
#  Run: 2/5 | Episode: 228/400 Episode: 227, Reward: 17.0
#  Run: 2/5 | Episode: 229/400 Episode: 228, Reward: 14.0
#  Run: 2/5 | Episode: 230/400 Episode: 229, Reward: 23.0
#  Run: 2/5 | Episode: 231/400 Episode: 230, Reward: 29.0
#  Run: 2/5 | Episode: 232/400 Episode: 231, Reward: 15.0
#  Run: 2/5 | Episode: 233/400 Episode: 232, Reward: 13.0
#  Run: 2/5 | Episode: 234/400 Episode: 233, Reward: 20.0
#  Run: 2/5 | Episode: 235/400 Episode: 234, Reward: 57.0
#  Run: 2/5 | Episode: 236/400 Episode: 235, Reward: 18.0
#  Run: 2/5 | Episode: 237/400 Episode: 236, Reward: 12.0
#  Run: 2/5 | Episode: 238/400 Episode: 237, Reward: 9.0
#  Run: 2/5 | Episode: 239/400 Episode: 238, Reward: 32.0
#  Run: 2/5 | Episode: 240/400 Episode: 239, Reward: 16.0
#  Run: 2/5 | Episode: 241/400 Episode: 240, Reward: 12.0
#  Run: 2/5 | Episode: 242/400 Episode: 241, Reward: 42.0
#  Run: 2/5 | Episode: 243/400 Episode: 242, Reward: 26.0
#  Run: 2/5 | Episode: 244/400 Episode: 243, Reward: 12.0
#  Run: 2/5 | Episode: 245/400 Episode: 244, Reward: 14.0
#  Run: 2/5 | Episode: 246/400 Episode: 245, Reward: 29.0
#  Run: 2/5 | Episode: 247/400 Episode: 246, Reward: 19.0
#  Run: 2/5 | Episode: 248/400 Episode: 247, Reward: 13.0
#  Run: 2/5 | Episode: 249/400 Episode: 248, Reward: 17.0
#  Run: 2/5 | Episode: 250/400 Episode: 249, Reward: 14.0
#  Run: 2/5 | Episode: 251/400 Episode: 250, Reward: 16.0
#  Run: 2/5 | Episode: 252/400 Episode: 251, Reward: 17.0
#  Run: 2/5 | Episode: 253/400 Episode: 252, Reward: 15.0
#  Run: 2/5 | Episode: 254/400 Episode: 253, Reward: 15.0
#  Run: 2/5 | Episode: 255/400 Episode: 254, Reward: 18.0
#  Run: 2/5 | Episode: 256/400 Episode: 255, Reward: 36.0
#  Run: 2/5 | Episode: 257/400 Episode: 256, Reward: 16.0
#  Run: 2/5 | Episode: 258/400 Episode: 257, Reward: 16.0
#  Run: 2/5 | Episode: 259/400 Episode: 258, Reward: 15.0
#  Run: 2/5 | Episode: 260/400 Episode: 259, Reward: 18.0
#  Run: 2/5 | Episode: 261/400 Episode: 260, Reward: 19.0
#  Run: 2/5 | Episode: 262/400 Episode: 261, Reward: 12.0
#  Run: 2/5 | Episode: 263/400 Episode: 262, Reward: 31.0
#  Run: 2/5 | Episode: 264/400 Episode: 263, Reward: 22.0
#  Run: 2/5 | Episode: 265/400 Episode: 264, Reward: 27.0
#  Run: 2/5 | Episode: 266/400 Episode: 265, Reward: 23.0
#  Run: 2/5 | Episode: 267/400 Episode: 266, Reward: 34.0
#  Run: 2/5 | Episode: 268/400 Episode: 267, Reward: 23.0
#  Run: 2/5 | Episode: 269/400 Episode: 268, Reward: 17.0
#  Run: 2/5 | Episode: 270/400 Episode: 269, Reward: 35.0
#  Run: 2/5 | Episode: 271/400 Episode: 270, Reward: 20.0
#  Run: 2/5 | Episode: 272/400 Episode: 271, Reward: 24.0
#  Run: 2/5 | Episode: 273/400 Episode: 272, Reward: 17.0
#  Run: 2/5 | Episode: 274/400 Episode: 273, Reward: 13.0
#  Run: 2/5 | Episode: 275/400 Episode: 274, Reward: 21.0
#  Run: 2/5 | Episode: 276/400 Episode: 275, Reward: 11.0
#  Run: 2/5 | Episode: 277/400 Episode: 276, Reward: 18.0
#  Run: 2/5 | Episode: 278/400 Episode: 277, Reward: 21.0
#  Run: 2/5 | Episode: 279/400 Episode: 278, Reward: 17.0
#  Run: 2/5 | Episode: 280/400 Episode: 279, Reward: 11.0
#  Run: 2/5 | Episode: 281/400 Episode: 280, Reward: 17.0
#  Run: 2/5 | Episode: 282/400 Episode: 281, Reward: 25.0
#  Run: 2/5 | Episode: 283/400 Episode: 282, Reward: 14.0
#  Run: 2/5 | Episode: 284/400 Episode: 283, Reward: 47.0
#  Run: 2/5 | Episode: 285/400 Episode: 284, Reward: 21.0
#  Run: 2/5 | Episode: 286/400 Episode: 285, Reward: 30.0
#  Run: 2/5 | Episode: 287/400 Episode: 286, Reward: 25.0
#  Run: 2/5 | Episode: 288/400 Episode: 287, Reward: 29.0
#  Run: 2/5 | Episode: 289/400 Episode: 288, Reward: 20.0
#  Run: 2/5 | Episode: 290/400 Episode: 289, Reward: 23.0
#  Run: 2/5 | Episode: 291/400 Episode: 290, Reward: 18.0
#  Run: 2/5 | Episode: 292/400 Episode: 291, Reward: 41.0
#  Run: 2/5 | Episode: 293/400 Episode: 292, Reward: 39.0
#  Run: 2/5 | Episode: 294/400 Episode: 293, Reward: 30.0
#  Run: 2/5 | Episode: 295/400 Episode: 294, Reward: 19.0
#  Run: 2/5 | Episode: 296/400 Episode: 295, Reward: 32.0
#  Run: 2/5 | Episode: 297/400 Episode: 296, Reward: 29.0
#  Run: 2/5 | Episode: 298/400 Episode: 297, Reward: 36.0
#  Run: 2/5 | Episode: 299/400 Episode: 298, Reward: 13.0
#  Run: 2/5 | Episode: 300/400 Episode: 299, Reward: 16.0
#  Run: 2/5 | Episode: 301/400 Episode: 300, Reward: 44.0
#  Run: 2/5 | Episode: 302/400 Episode: 301, Reward: 13.0
#  Run: 2/5 | Episode: 303/400 Episode: 302, Reward: 14.0
#  Run: 2/5 | Episode: 304/400 Episode: 303, Reward: 13.0
#  Run: 2/5 | Episode: 305/400 Episode: 304, Reward: 34.0
#  Run: 2/5 | Episode: 306/400 Episode: 305, Reward: 27.0
#  Run: 2/5 | Episode: 307/400 Episode: 306, Reward: 16.0
#  Run: 2/5 | Episode: 308/400 Episode: 307, Reward: 11.0
#  Run: 2/5 | Episode: 309/400 Episode: 308, Reward: 109.0
#  Run: 2/5 | Episode: 310/400 Episode: 309, Reward: 55.0
#  Run: 2/5 | Episode: 311/400 Episode: 310, Reward: 18.0
#  Run: 2/5 | Episode: 312/400 Episode: 311, Reward: 39.0
#  Run: 2/5 | Episode: 313/400 Episode: 312, Reward: 500.0
#  Run: 2/5 | Episode: 314/400 Episode: 313, Reward: 55.0
#  Run: 2/5 | Episode: 315/400 Episode: 314, Reward: 15.0
#  Run: 2/5 | Episode: 316/400 Episode: 315, Reward: 14.0
#  Run: 2/5 | Episode: 317/400 Episode: 316, Reward: 500.0
#  Run: 2/5 | Episode: 318/400 Episode: 317, Reward: 31.0
#  Run: 2/5 | Episode: 319/400 Episode: 318, Reward: 50.0
#  Run: 2/5 | Episode: 320/400 Episode: 319, Reward: 18.0
#  Run: 2/5 | Episode: 321/400 Episode: 320, Reward: 387.0
#  Run: 2/5 | Episode: 322/400 Episode: 321, Reward: 12.0
#  Run: 2/5 | Episode: 323/400 Episode: 322, Reward: 15.0
#  Run: 2/5 | Episode: 324/400 Episode: 323, Reward: 59.0
#  Run: 2/5 | Episode: 325/400 Episode: 324, Reward: 500.0
#  Run: 2/5 | Episode: 326/400 Episode: 325, Reward: 23.0
#  Run: 2/5 | Episode: 327/400 Episode: 326, Reward: 12.0
#  Run: 2/5 | Episode: 328/400 Episode: 327, Reward: 13.0
#  Run: 2/5 | Episode: 329/400 Episode: 328, Reward: 423.0
#  Run: 2/5 | Episode: 330/400 Episode: 329, Reward: 25.0
#  Run: 2/5 | Episode: 331/400 Episode: 330, Reward: 15.0
#  Run: 2/5 | Episode: 332/400 Episode: 331, Reward: 16.0
#  Run: 2/5 | Episode: 333/400 Episode: 332, Reward: 292.0
#  Run: 2/5 | Episode: 334/400 Episode: 333, Reward: 16.0
#  Run: 2/5 | Episode: 335/400 Episode: 334, Reward: 13.0
#  Run: 2/5 | Episode: 336/400 Episode: 335, Reward: 20.0
#  Run: 2/5 | Episode: 337/400 Episode: 336, Reward: 404.0
#  Run: 2/5 | Episode: 338/400 Episode: 337, Reward: 28.0
#  Run: 2/5 | Episode: 339/400 Episode: 338, Reward: 27.0
#  Run: 2/5 | Episode: 340/400 Episode: 339, Reward: 17.0
#  Run: 2/5 | Episode: 341/400 Episode: 340, Reward: 383.0
#  Run: 2/5 | Episode: 342/400 Episode: 341, Reward: 12.0
#  Run: 2/5 | Episode: 343/400 Episode: 342, Reward: 46.0
#  Run: 2/5 | Episode: 344/400 Episode: 343, Reward: 89.0
#  Run: 2/5 | Episode: 345/400 Episode: 344, Reward: 359.0
#  Run: 2/5 | Episode: 346/400 Episode: 345, Reward: 15.0
#  Run: 2/5 | Episode: 347/400 Episode: 346, Reward: 72.0
#  Run: 2/5 | Episode: 348/400 Episode: 347, Reward: 10.0
#  Run: 2/5 | Episode: 349/400 Episode: 348, Reward: 259.0
#  Run: 2/5 | Episode: 350/400 Episode: 349, Reward: 39.0
#  Run: 2/5 | Episode: 351/400 Episode: 350, Reward: 11.0
#  Run: 2/5 | Episode: 352/400 Episode: 351, Reward: 11.0
#  Run: 2/5 | Episode: 353/400 Episode: 352, Reward: 238.0
#  Run: 2/5 | Episode: 354/400 Episode: 353, Reward: 16.0
#  Run: 2/5 | Episode: 355/400 Episode: 354, Reward: 26.0
#  Run: 2/5 | Episode: 356/400 Episode: 355, Reward: 18.0
#  Run: 2/5 | Episode: 357/400 Episode: 356, Reward: 193.0
#  Run: 2/5 | Episode: 358/400 Episode: 357, Reward: 15.0
#  Run: 2/5 | Episode: 359/400 Episode: 358, Reward: 22.0
#  Run: 2/5 | Episode: 360/400 Episode: 359, Reward: 14.0
#  Run: 2/5 | Episode: 361/400 Episode: 360, Reward: 151.0
#  Run: 2/5 | Episode: 362/400 Episode: 361, Reward: 13.0
#  Run: 2/5 | Episode: 363/400 Episode: 362, Reward: 21.0
#  Run: 2/5 | Episode: 364/400 Episode: 363, Reward: 12.0
#  Run: 2/5 | Episode: 365/400 Episode: 364, Reward: 223.0
#  Run: 2/5 | Episode: 366/400 Episode: 365, Reward: 37.0
#  Run: 2/5 | Episode: 367/400 Episode: 366, Reward: 17.0
#  Run: 2/5 | Episode: 368/400 Episode: 367, Reward: 17.0
#  Run: 2/5 | Episode: 369/400 Episode: 368, Reward: 185.0
#  Run: 2/5 | Episode: 370/400 Episode: 369, Reward: 29.0
#  Run: 2/5 | Episode: 371/400 Episode: 370, Reward: 22.0
#  Run: 2/5 | Episode: 372/400 Episode: 371, Reward: 15.0
#  Run: 2/5 | Episode: 373/400 Episode: 372, Reward: 243.0
#  Run: 2/5 | Episode: 374/400 Episode: 373, Reward: 29.0
#  Run: 2/5 | Episode: 375/400 Episode: 374, Reward: 23.0
#  Run: 2/5 | Episode: 376/400 Episode: 375, Reward: 39.0
#  Run: 2/5 | Episode: 377/400 Episode: 376, Reward: 192.0
#  Run: 2/5 | Episode: 378/400 Episode: 377, Reward: 32.0
#  Run: 2/5 | Episode: 379/400 Episode: 378, Reward: 25.0
#  Run: 2/5 | Episode: 380/400 Episode: 379, Reward: 30.0
#  Run: 2/5 | Episode: 381/400 Episode: 380, Reward: 148.0
#  Run: 2/5 | Episode: 382/400 Episode: 381, Reward: 24.0
#  Run: 2/5 | Episode: 383/400 Episode: 382, Reward: 17.0
#  Run: 2/5 | Episode: 384/400 Episode: 383, Reward: 47.0
#  Run: 2/5 | Episode: 385/400 Episode: 384, Reward: 152.0
#  Run: 2/5 | Episode: 386/400 Episode: 385, Reward: 10.0
#  Run: 2/5 | Episode: 387/400 Episode: 386, Reward: 40.0
#  Run: 2/5 | Episode: 388/400 Episode: 387, Reward: 27.0
#  Run: 2/5 | Episode: 389/400 Episode: 388, Reward: 168.0
#  Run: 2/5 | Episode: 390/400 Episode: 389, Reward: 20.0
#  Run: 2/5 | Episode: 391/400 Episode: 390, Reward: 102.0
#  Run: 2/5 | Episode: 392/400 Episode: 391, Reward: 11.0
#  Run: 2/5 | Episode: 393/400 Episode: 392, Reward: 195.0
#  Run: 2/5 | Episode: 394/400 Episode: 393, Reward: 12.0
#  Run: 2/5 | Episode: 395/400 Episode: 394, Reward: 16.0
#  Run: 2/5 | Episode: 396/400 Episode: 395, Reward: 35.0
#  Run: 2/5 | Episode: 397/400 Episode: 396, Reward: 202.0
#  Run: 2/5 | Episode: 398/400 Episode: 397, Reward: 11.0
#  Run: 2/5 | Episode: 399/400 Episode: 398, Reward: 12.0
#  Run: 2/5 | Episode: 400/400 Episode: 399, Reward: 39.0
#  Run: 3/5 | Episode: 1/400 Episode: 0, Reward: 15.0
#  Run: 3/5 | Episode: 2/400 Episode: 1, Reward: 20.0
#  Run: 3/5 | Episode: 3/400 Episode: 2, Reward: 30.0
#  Run: 3/5 | Episode: 4/400 Episode: 3, Reward: 15.0
#  Run: 3/5 | Episode: 5/400 Episode: 4, Reward: 14.0
#  Run: 3/5 | Episode: 6/400 Episode: 5, Reward: 17.0
#  Run: 3/5 | Episode: 7/400 Episode: 6, Reward: 10.0
#  Run: 3/5 | Episode: 8/400 Episode: 7, Reward: 20.0
#  Run: 3/5 | Episode: 9/400 Episode: 8, Reward: 10.0
#  Run: 3/5 | Episode: 10/400 Episode: 9, Reward: 14.0
#  Run: 3/5 | Episode: 11/400 Episode: 10, Reward: 17.0
#  Run: 3/5 | Episode: 12/400 Episode: 11, Reward: 9.0
#  Run: 3/5 | Episode: 13/400 Episode: 12, Reward: 12.0
#  Run: 3/5 | Episode: 14/400 Episode: 13, Reward: 21.0
#  Run: 3/5 | Episode: 15/400 Episode: 14, Reward: 9.0
#  Run: 3/5 | Episode: 16/400 Episode: 15, Reward: 48.0
#  Run: 3/5 | Episode: 17/400 Episode: 16, Reward: 18.0
#  Run: 3/5 | Episode: 18/400 Episode: 17, Reward: 23.0
#  Run: 3/5 | Episode: 19/400 Episode: 18, Reward: 30.0
#  Run: 3/5 | Episode: 20/400 Episode: 19, Reward: 15.0
#  Run: 3/5 | Episode: 21/400 Episode: 20, Reward: 12.0
#  Run: 3/5 | Episode: 22/400 Episode: 21, Reward: 18.0
#  Run: 3/5 | Episode: 23/400 Episode: 22, Reward: 14.0
#  Run: 3/5 | Episode: 24/400 Episode: 23, Reward: 14.0
#  Run: 3/5 | Episode: 25/400 Episode: 24, Reward: 16.0
#  Run: 3/5 | Episode: 26/400 Episode: 25, Reward: 12.0
#  Run: 3/5 | Episode: 27/400 Episode: 26, Reward: 24.0
#  Run: 3/5 | Episode: 28/400 Episode: 27, Reward: 15.0
#  Run: 3/5 | Episode: 29/400 Episode: 28, Reward: 19.0
#  Run: 3/5 | Episode: 30/400 Episode: 29, Reward: 27.0
#  Run: 3/5 | Episode: 31/400 Episode: 30, Reward: 14.0
#  Run: 3/5 | Episode: 32/400 Episode: 31, Reward: 32.0
#  Run: 3/5 | Episode: 33/400 Episode: 32, Reward: 18.0
#  Run: 3/5 | Episode: 34/400 Episode: 33, Reward: 46.0
#  Run: 3/5 | Episode: 35/400 Episode: 34, Reward: 19.0
#  Run: 3/5 | Episode: 36/400 Episode: 35, Reward: 12.0
#  Run: 3/5 | Episode: 37/400 Episode: 36, Reward: 11.0
#  Run: 3/5 | Episode: 38/400 Episode: 37, Reward: 21.0
#  Run: 3/5 | Episode: 39/400 Episode: 38, Reward: 32.0
#  Run: 3/5 | Episode: 40/400 Episode: 39, Reward: 15.0
#  Run: 3/5 | Episode: 41/400 Episode: 40, Reward: 10.0
#  Run: 3/5 | Episode: 42/400 Episode: 41, Reward: 17.0
#  Run: 3/5 | Episode: 43/400 Episode: 42, Reward: 19.0
#  Run: 3/5 | Episode: 44/400 Episode: 43, Reward: 19.0
#  Run: 3/5 | Episode: 45/400 Episode: 44, Reward: 9.0
#  Run: 3/5 | Episode: 46/400 Episode: 45, Reward: 28.0
#  Run: 3/5 | Episode: 47/400 Episode: 46, Reward: 22.0
#  Run: 3/5 | Episode: 48/400 Episode: 47, Reward: 20.0
#  Run: 3/5 | Episode: 49/400 Episode: 48, Reward: 8.0
#  Run: 3/5 | Episode: 50/400 Episode: 49, Reward: 13.0
#  Run: 3/5 | Episode: 51/400 Episode: 50, Reward: 11.0
#  Run: 3/5 | Episode: 52/400 Episode: 51, Reward: 12.0
#  Run: 3/5 | Episode: 53/400 Episode: 52, Reward: 8.0
#  Run: 3/5 | Episode: 54/400 Episode: 53, Reward: 12.0
#  Run: 3/5 | Episode: 55/400 Episode: 54, Reward: 26.0
#  Run: 3/5 | Episode: 56/400 Episode: 55, Reward: 17.0
#  Run: 3/5 | Episode: 57/400 Episode: 56, Reward: 10.0
#  Run: 3/5 | Episode: 58/400 Episode: 57, Reward: 37.0
#  Run: 3/5 | Episode: 59/400 Episode: 58, Reward: 12.0
#  Run: 3/5 | Episode: 60/400 Episode: 59, Reward: 11.0
#  Run: 3/5 | Episode: 61/400 Episode: 60, Reward: 9.0
#  Run: 3/5 | Episode: 62/400 Episode: 61, Reward: 37.0
#  Run: 3/5 | Episode: 63/400 Episode: 62, Reward: 17.0
#  Run: 3/5 | Episode: 64/400 Episode: 63, Reward: 13.0
#  Run: 3/5 | Episode: 65/400 Episode: 64, Reward: 8.0
#  Run: 3/5 | Episode: 66/400 Episode: 65, Reward: 15.0
#  Run: 3/5 | Episode: 67/400 Episode: 66, Reward: 14.0
# ...
#  Run: 3/5 | Episode: 312/400 Episode: 311, Reward: 21.0
#  Run: 3/5 | Episode: 313/400 Episode: 312, Reward: 88.0
#  Run: 3/5 | Episode: 314/400 Episode: 313, Reward: 16.0
#  Run: 3/5 | Episode: 315/400 Episode: 314, Reward: 49.0
#  Run: 3/5 | Episode: 316/400 Episode: 315, Reward: 19.0
#  Run: 3/5 | Episode: 317/400 Episode: 316, Reward: 57.0
#  Run: 3/5 | Episode: 318/400 Episode: 317, Reward: 23.0
#  Run: 3/5 | Episode: 319/400 Episode: 318, Reward: 17.0
#  Run: 3/5 | Episode: 320/400 Episode: 319, Reward: 13.0
#  Run: 3/5 | Episode: 321/400 Episode: 320, Reward: 229.0
#  Run: 3/5 | Episode: 322/400 Episode: 321, Reward: 13.0
#  Run: 3/5 | Episode: 323/400 Episode: 322, Reward: 30.0
#  Run: 3/5 | Episode: 324/400 Episode: 323, Reward: 17.0
#  Run: 3/5 | Episode: 325/400 Episode: 324, Reward: 59.0
#  Run: 3/5 | Episode: 326/400 Episode: 325, Reward: 20.0
#  Run: 3/5 | Episode: 327/400 Episode: 326, Reward: 18.0
#  Run: 3/5 | Episode: 328/400 Episode: 327, Reward: 13.0
#  Run: 3/5 | Episode: 329/400 Episode: 328, Reward: 68.0
#  Run: 3/5 | Episode: 330/400 Episode: 329, Reward: 13.0
#  Run: 3/5 | Episode: 331/400 Episode: 330, Reward: 32.0
#  Run: 3/5 | Episode: 332/400 Episode: 331, Reward: 36.0
#  Run: 3/5 | Episode: 333/400 Episode: 332, Reward: 11.0
#  Run: 3/5 | Episode: 334/400 Episode: 333, Reward: 16.0
#  Run: 3/5 | Episode: 335/400 Episode: 334, Reward: 28.0
#  Run: 3/5 | Episode: 336/400 Episode: 335, Reward: 10.0
#  Run: 3/5 | Episode: 337/400 Episode: 336, Reward: 96.0
#  Run: 3/5 | Episode: 338/400 Episode: 337, Reward: 14.0
#  Run: 3/5 | Episode: 339/400 Episode: 338, Reward: 25.0
#  Run: 3/5 | Episode: 340/400 Episode: 339, Reward: 48.0
#  Run: 3/5 | Episode: 341/400 Episode: 340, Reward: 84.0
#  Run: 3/5 | Episode: 342/400 Episode: 341, Reward: 18.0
#  Run: 3/5 | Episode: 343/400 Episode: 342, Reward: 33.0
#  Run: 3/5 | Episode: 344/400 Episode: 343, Reward: 8.0
#  Run: 3/5 | Episode: 345/400 Episode: 344, Reward: 11.0
#  Run: 3/5 | Episode: 346/400 Episode: 345, Reward: 45.0
#  Run: 3/5 | Episode: 347/400 Episode: 346, Reward: 10.0
#  Run: 3/5 | Episode: 348/400 Episode: 347, Reward: 46.0
#  Run: 3/5 | Episode: 349/400 Episode: 348, Reward: 84.0
#  Run: 3/5 | Episode: 350/400 Episode: 349, Reward: 30.0
#  Run: 3/5 | Episode: 351/400 Episode: 350, Reward: 35.0
#  Run: 3/5 | Episode: 352/400 Episode: 351, Reward: 27.0
#  Run: 3/5 | Episode: 353/400 Episode: 352, Reward: 122.0
#  Run: 3/5 | Episode: 354/400 Episode: 353, Reward: 15.0
#  Run: 3/5 | Episode: 355/400 Episode: 354, Reward: 28.0
#  Run: 3/5 | Episode: 356/400 Episode: 355, Reward: 17.0
#  Run: 3/5 | Episode: 357/400 Episode: 356, Reward: 47.0
#  Run: 3/5 | Episode: 358/400 Episode: 357, Reward: 17.0
#  Run: 3/5 | Episode: 359/400 Episode: 358, Reward: 12.0
#  Run: 3/5 | Episode: 360/400 Episode: 359, Reward: 18.0
#  Run: 3/5 | Episode: 361/400 Episode: 360, Reward: 95.0
#  Run: 3/5 | Episode: 362/400 Episode: 361, Reward: 19.0
#  Run: 3/5 | Episode: 363/400 Episode: 362, Reward: 23.0
#  Run: 3/5 | Episode: 364/400 Episode: 363, Reward: 11.0
#  Run: 3/5 | Episode: 365/400 Episode: 364, Reward: 102.0
#  Run: 3/5 | Episode: 366/400 Episode: 365, Reward: 27.0
#  Run: 3/5 | Episode: 367/400 Episode: 366, Reward: 19.0
#  Run: 3/5 | Episode: 368/400 Episode: 367, Reward: 21.0
#  Run: 3/5 | Episode: 369/400 Episode: 368, Reward: 57.0
#  Run: 3/5 | Episode: 370/400 Episode: 369, Reward: 13.0
#  Run: 3/5 | Episode: 371/400 Episode: 370, Reward: 20.0
#  Run: 3/5 | Episode: 372/400 Episode: 371, Reward: 46.0
#  Run: 3/5 | Episode: 373/400 Episode: 372, Reward: 132.0
#  Run: 3/5 | Episode: 374/400 Episode: 373, Reward: 41.0
#  Run: 3/5 | Episode: 375/400 Episode: 374, Reward: 9.0
#  Run: 3/5 | Episode: 376/400 Episode: 375, Reward: 32.0
#  Run: 3/5 | Episode: 377/400 Episode: 376, Reward: 50.0
#  Run: 3/5 | Episode: 378/400 Episode: 377, Reward: 62.0
#  Run: 3/5 | Episode: 379/400 Episode: 378, Reward: 29.0
#  Run: 3/5 | Episode: 380/400 Episode: 379, Reward: 16.0
#  Run: 3/5 | Episode: 381/400 Episode: 380, Reward: 140.0
#  Run: 3/5 | Episode: 382/400 Episode: 381, Reward: 11.0
#  Run: 3/5 | Episode: 383/400 Episode: 382, Reward: 13.0
#  Run: 3/5 | Episode: 384/400 Episode: 383, Reward: 98.0
#  Run: 3/5 | Episode: 385/400 Episode: 384, Reward: 202.0
#  Run: 3/5 | Episode: 386/400 Episode: 385, Reward: 18.0
#  Run: 3/5 | Episode: 387/400 Episode: 386, Reward: 23.0
#  Run: 3/5 | Episode: 388/400 Episode: 387, Reward: 15.0
#  Run: 3/5 | Episode: 389/400 Episode: 388, Reward: 23.0
#  Run: 3/5 | Episode: 390/400 Episode: 389, Reward: 12.0
#  Run: 3/5 | Episode: 391/400 Episode: 390, Reward: 44.0
#  Run: 3/5 | Episode: 392/400 Episode: 391, Reward: 16.0
#  Run: 3/5 | Episode: 393/400 Episode: 392, Reward: 27.0
#  Run: 3/5 | Episode: 394/400 Episode: 393, Reward: 8.0
#  Run: 3/5 | Episode: 395/400 Episode: 394, Reward: 13.0
#  Run: 3/5 | Episode: 396/400 Episode: 395, Reward: 26.0
#  Run: 3/5 | Episode: 397/400 Episode: 396, Reward: 40.0
#  Run: 3/5 | Episode: 398/400 Episode: 397, Reward: 40.0
#  Run: 3/5 | Episode: 399/400 Episode: 398, Reward: 37.0
#  Run: 3/5 | Episode: 400/400 Episode: 399, Reward: 13.0
#  Run: 4/5 | Episode: 1/400 Episode: 0, Reward: 23.0
#  Run: 4/5 | Episode: 2/400 Episode: 1, Reward: 15.0
#  Run: 4/5 | Episode: 3/400 Episode: 2, Reward: 12.0
#  Run: 4/5 | Episode: 4/400 Episode: 3, Reward: 16.0
#  Run: 4/5 | Episode: 5/400 Episode: 4, Reward: 59.0
#  Run: 4/5 | Episode: 6/400 Episode: 5, Reward: 15.0
#  Run: 4/5 | Episode: 7/400 Episode: 6, Reward: 19.0
#  Run: 4/5 | Episode: 8/400 Episode: 7, Reward: 13.0
#  Run: 4/5 | Episode: 9/400 Episode: 8, Reward: 39.0
#  Run: 4/5 | Episode: 10/400 Episode: 9, Reward: 11.0
#  Run: 4/5 | Episode: 11/400 Episode: 10, Reward: 33.0
#  Run: 4/5 | Episode: 12/400 Episode: 11, Reward: 15.0
#  Run: 4/5 | Episode: 13/400 Episode: 12, Reward: 11.0
#  Run: 4/5 | Episode: 14/400 Episode: 13, Reward: 18.0
#  Run: 4/5 | Episode: 15/400 Episode: 14, Reward: 17.0
#  Run: 4/5 | Episode: 16/400 Episode: 15, Reward: 33.0
#  Run: 4/5 | Episode: 17/400 Episode: 16, Reward: 9.0
#  Run: 4/5 | Episode: 18/400 Episode: 17, Reward: 30.0
#  Run: 4/5 | Episode: 19/400 Episode: 18, Reward: 12.0
#  Run: 4/5 | Episode: 20/400 Episode: 19, Reward: 33.0
#  Run: 4/5 | Episode: 21/400 Episode: 20, Reward: 8.0
#  Run: 4/5 | Episode: 22/400 Episode: 21, Reward: 33.0
#  Run: 4/5 | Episode: 23/400 Episode: 22, Reward: 31.0
#  Run: 4/5 | Episode: 24/400 Episode: 23, Reward: 20.0
#  Run: 4/5 | Episode: 25/400 Episode: 24, Reward: 10.0
#  Run: 4/5 | Episode: 26/400 Episode: 25, Reward: 13.0
#  Run: 4/5 | Episode: 27/400 Episode: 26, Reward: 70.0
#  Run: 4/5 | Episode: 28/400 Episode: 27, Reward: 32.0
#  Run: 4/5 | Episode: 29/400 Episode: 28, Reward: 14.0
#  Run: 4/5 | Episode: 30/400 Episode: 29, Reward: 20.0
#  Run: 4/5 | Episode: 31/400 Episode: 30, Reward: 39.0
#  Run: 4/5 | Episode: 32/400 Episode: 31, Reward: 26.0
#  Run: 4/5 | Episode: 33/400 Episode: 32, Reward: 51.0
#  Run: 4/5 | Episode: 34/400 Episode: 33, Reward: 21.0
#  Run: 4/5 | Episode: 35/400 Episode: 34, Reward: 18.0
#  Run: 4/5 | Episode: 36/400 Episode: 35, Reward: 42.0
#  Run: 4/5 | Episode: 37/400 Episode: 36, Reward: 18.0
#  Run: 4/5 | Episode: 38/400 Episode: 37, Reward: 21.0
#  Run: 4/5 | Episode: 39/400 Episode: 38, Reward: 57.0
#  Run: 4/5 | Episode: 40/400 Episode: 39, Reward: 14.0
#  Run: 4/5 | Episode: 41/400 Episode: 40, Reward: 39.0
#  Run: 4/5 | Episode: 42/400 Episode: 41, Reward: 15.0
#  Run: 4/5 | Episode: 43/400 Episode: 42, Reward: 17.0
#  Run: 4/5 | Episode: 44/400 Episode: 43, Reward: 23.0
#  Run: 4/5 | Episode: 45/400 Episode: 44, Reward: 16.0
#  Run: 4/5 | Episode: 46/400 Episode: 45, Reward: 11.0
#  Run: 4/5 | Episode: 47/400 Episode: 46, Reward: 8.0
#  Run: 4/5 | Episode: 48/400 Episode: 47, Reward: 12.0
#  Run: 4/5 | Episode: 49/400 Episode: 48, Reward: 11.0
#  Run: 4/5 | Episode: 50/400 Episode: 49, Reward: 32.0
#  Run: 4/5 | Episode: 51/400 Episode: 50, Reward: 23.0
#  Run: 4/5 | Episode: 52/400 Episode: 51, Reward: 14.0
#  Run: 4/5 | Episode: 53/400 Episode: 52, Reward: 11.0
#  Run: 4/5 | Episode: 54/400 Episode: 53, Reward: 17.0
#  Run: 4/5 | Episode: 55/400 Episode: 54, Reward: 21.0
#  Run: 4/5 | Episode: 56/400 Episode: 55, Reward: 24.0
#  Run: 4/5 | Episode: 57/400 Episode: 56, Reward: 9.0
#  Run: 4/5 | Episode: 58/400 Episode: 57, Reward: 12.0
#  Run: 4/5 | Episode: 59/400 Episode: 58, Reward: 12.0
#  Run: 4/5 | Episode: 60/400 Episode: 59, Reward: 27.0
#  Run: 4/5 | Episode: 61/400 Episode: 60, Reward: 9.0
#  Run: 4/5 | Episode: 62/400 Episode: 61, Reward: 18.0
#  Run: 4/5 | Episode: 63/400 Episode: 62, Reward: 31.0
#  Run: 4/5 | Episode: 64/400 Episode: 63, Reward: 40.0
#  Run: 4/5 | Episode: 65/400 Episode: 64, Reward: 8.0
#  Run: 4/5 | Episode: 66/400 Episode: 65, Reward: 12.0
#  Run: 4/5 | Episode: 67/400 Episode: 66, Reward: 16.0
#  Run: 4/5 | Episode: 68/400 Episode: 67, Reward: 39.0
#  Run: 4/5 | Episode: 69/400 Episode: 68, Reward: 11.0
#  Run: 4/5 | Episode: 70/400 Episode: 69, Reward: 12.0
#  Run: 4/5 | Episode: 71/400 Episode: 70, Reward: 9.0
#  Run: 4/5 | Episode: 72/400 Episode: 71, Reward: 23.0
#  Run: 4/5 | Episode: 73/400 Episode: 72, Reward: 11.0
#  Run: 4/5 | Episode: 74/400 Episode: 73, Reward: 41.0
#  Run: 4/5 | Episode: 75/400 Episode: 74, Reward: 11.0
#  Run: 4/5 | Episode: 76/400 Episode: 75, Reward: 14.0
#  Run: 4/5 | Episode: 77/400 Episode: 76, Reward: 10.0
#  Run: 4/5 | Episode: 78/400 Episode: 77, Reward: 44.0
#  Run: 4/5 | Episode: 79/400 Episode: 78, Reward: 19.0
#  Run: 4/5 | Episode: 80/400 Episode: 79, Reward: 20.0
#  Run: 4/5 | Episode: 81/400 Episode: 80, Reward: 9.0
#  Run: 4/5 | Episode: 82/400 Episode: 81, Reward: 26.0
#  Run: 4/5 | Episode: 83/400 Episode: 82, Reward: 11.0
#  Run: 4/5 | Episode: 84/400 Episode: 83, Reward: 20.0
#  Run: 4/5 | Episode: 85/400 Episode: 84, Reward: 9.0
#  Run: 4/5 | Episode: 86/400 Episode: 85, Reward: 15.0
#  Run: 4/5 | Episode: 87/400 Episode: 86, Reward: 29.0
#  Run: 4/5 | Episode: 88/400 Episode: 87, Reward: 12.0
#  Run: 4/5 | Episode: 89/400 Episode: 88, Reward: 11.0
#  Run: 4/5 | Episode: 90/400 Episode: 89, Reward: 26.0
#  Run: 4/5 | Episode: 91/400 Episode: 90, Reward: 50.0
#  Run: 4/5 | Episode: 92/400 Episode: 91, Reward: 42.0
#  Run: 4/5 | Episode: 93/400 Episode: 92, Reward: 11.0
#  Run: 4/5 | Episode: 94/400 Episode: 93, Reward: 14.0
#  Run: 4/5 | Episode: 95/400 Episode: 94, Reward: 32.0
#  Run: 4/5 | Episode: 96/400 Episode: 95, Reward: 27.0
#  Run: 4/5 | Episode: 97/400 Episode: 96, Reward: 15.0
#  Run: 4/5 | Episode: 98/400 Episode: 97, Reward: 17.0
#  Run: 4/5 | Episode: 99/400 Episode: 98, Reward: 22.0
#  Run: 4/5 | Episode: 100/400 Episode: 99, Reward: 21.0
#  Run: 4/5 | Episode: 101/400 Episode: 100, Reward: 12.0
#  Run: 4/5 | Episode: 102/400 Episode: 101, Reward: 29.0
#  Run: 4/5 | Episode: 103/400 Episode: 102, Reward: 15.0
#  Run: 4/5 | Episode: 104/400 Episode: 103, Reward: 41.0
#  Run: 4/5 | Episode: 105/400 Episode: 104, Reward: 11.0
#  Run: 4/5 | Episode: 106/400 Episode: 105, Reward: 10.0
#  Run: 4/5 | Episode: 107/400 Episode: 106, Reward: 13.0
#  Run: 4/5 | Episode: 108/400 Episode: 107, Reward: 17.0
#  Run: 4/5 | Episode: 109/400 Episode: 108, Reward: 12.0
#  Run: 4/5 | Episode: 110/400 Episode: 109, Reward: 11.0
#  Run: 4/5 | Episode: 111/400 Episode: 110, Reward: 27.0
#  Run: 4/5 | Episode: 112/400 Episode: 111, Reward: 21.0
#  Run: 4/5 | Episode: 113/400 Episode: 112, Reward: 12.0
#  Run: 4/5 | Episode: 114/400 Episode: 113, Reward: 58.0
#  Run: 4/5 | Episode: 115/400 Episode: 114, Reward: 19.0
#  Run: 4/5 | Episode: 116/400 Episode: 115, Reward: 13.0
#  Run: 4/5 | Episode: 117/400 Episode: 116, Reward: 11.0
#  Run: 4/5 | Episode: 118/400 Episode: 117, Reward: 33.0
#  Run: 4/5 | Episode: 119/400 Episode: 118, Reward: 17.0
#  Run: 4/5 | Episode: 120/400 Episode: 119, Reward: 17.0
#  Run: 4/5 | Episode: 121/400 Episode: 120, Reward: 9.0
#  Run: 4/5 | Episode: 122/400 Episode: 121, Reward: 9.0
#  Run: 4/5 | Episode: 123/400 Episode: 122, Reward: 21.0
#  Run: 4/5 | Episode: 124/400 Episode: 123, Reward: 12.0
#  Run: 4/5 | Episode: 125/400 Episode: 124, Reward: 12.0
#  Run: 4/5 | Episode: 126/400 Episode: 125, Reward: 31.0
#  Run: 4/5 | Episode: 127/400 Episode: 126, Reward: 13.0
#  Run: 4/5 | Episode: 128/400 Episode: 127, Reward: 18.0
#  Run: 4/5 | Episode: 129/400 Episode: 128, Reward: 10.0
#  Run: 4/5 | Episode: 130/400 Episode: 129, Reward: 13.0
#  Run: 4/5 | Episode: 131/400 Episode: 130, Reward: 21.0
#  Run: 4/5 | Episode: 132/400 Episode: 131, Reward: 13.0
#  Run: 4/5 | Episode: 133/400 Episode: 132, Reward: 17.0
#  Run: 4/5 | Episode: 134/400 Episode: 133, Reward: 10.0
#  Run: 4/5 | Episode: 135/400 Episode: 134, Reward: 23.0
#  Run: 4/5 | Episode: 136/400 Episode: 135, Reward: 18.0
#  Run: 4/5 | Episode: 137/400 Episode: 136, Reward: 10.0
#  Run: 4/5 | Episode: 138/400 Episode: 137, Reward: 19.0
#  Run: 4/5 | Episode: 139/400 Episode: 138, Reward: 19.0
#  Run: 4/5 | Episode: 140/400 Episode: 139, Reward: 53.0
#  Run: 4/5 | Episode: 141/400 Episode: 140, Reward: 10.0
#  Run: 4/5 | Episode: 142/400 Episode: 141, Reward: 24.0
#  Run: 4/5 | Episode: 143/400 Episode: 142, Reward: 51.0
#  Run: 4/5 | Episode: 144/400 Episode: 143, Reward: 24.0
#  Run: 4/5 | Episode: 145/400 Episode: 144, Reward: 11.0
#  Run: 4/5 | Episode: 146/400 Episode: 145, Reward: 10.0
#  Run: 4/5 | Episode: 147/400 Episode: 146, Reward: 10.0
#  Run: 4/5 | Episode: 148/400 Episode: 147, Reward: 43.0
#  Run: 4/5 | Episode: 149/400 Episode: 148, Reward: 11.0
#  Run: 4/5 | Episode: 150/400 Episode: 149, Reward: 22.0
#  Run: 4/5 | Episode: 151/400 Episode: 150, Reward: 21.0
#  Run: 4/5 | Episode: 152/400 Episode: 151, Reward: 24.0
#  Run: 4/5 | Episode: 153/400 Episode: 152, Reward: 17.0
#  Run: 4/5 | Episode: 154/400 Episode: 153, Reward: 32.0
#  Run: 4/5 | Episode: 155/400 Episode: 154, Reward: 24.0
#  Run: 4/5 | Episode: 156/400 Episode: 155, Reward: 17.0
#  Run: 4/5 | Episode: 157/400 Episode: 156, Reward: 15.0
#  Run: 4/5 | Episode: 158/400 Episode: 157, Reward: 22.0
#  Run: 4/5 | Episode: 159/400 Episode: 158, Reward: 19.0
#  Run: 4/5 | Episode: 160/400 Episode: 159, Reward: 16.0
#  Run: 4/5 | Episode: 161/400 Episode: 160, Reward: 15.0
#  Run: 4/5 | Episode: 162/400 Episode: 161, Reward: 20.0
#  Run: 4/5 | Episode: 163/400 Episode: 162, Reward: 50.0
#  Run: 4/5 | Episode: 164/400 Episode: 163, Reward: 19.0
#  Run: 4/5 | Episode: 165/400 Episode: 164, Reward: 39.0
#  Run: 4/5 | Episode: 166/400 Episode: 165, Reward: 15.0
#  Run: 4/5 | Episode: 167/400 Episode: 166, Reward: 56.0
#  Run: 4/5 | Episode: 168/400 Episode: 167, Reward: 11.0
#  Run: 4/5 | Episode: 169/400 Episode: 168, Reward: 18.0
#  Run: 4/5 | Episode: 170/400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 269
#     267 next_state, reward, done, info = env.step(action)
#     268 if not evaluation_episode:
# --> 269     agent.train_on_transition(state, action, next_state, reward, done)
#     270 episode_reward += reward
#     271 state = next_state
#
# Cell In[6], line 136, in SACAgent.train_on_transition(self, state, discrete_action, next_state, reward, done)
#     134 def train_on_transition(self, state, discrete_action, next_state, reward, done):
#     135     transition = (state, discrete_action, reward, next_state, done)
# --> 136     self.train_networks(transition)
#
# Cell In[6], line 150, in SACAgent.train_networks(self, transition)
#     146 # Compute the gradients based on this loss, i.e. the gradients of the loss with respect to the Q-network
#     147 # parameters.
#     148 if self.replay_buffer.get_size() >= self.REPLAY_BUFFER_BATCH_SIZE:
#     149     # get minibatch of 100 transitions from replay buffer
# --> 150     minibatch = self.replay_buffer.sample_minibatch(self.REPLAY_BUFFER_BATCH_SIZE)
#     151     minibatch_separated = list(map(list, zip(*minibatch)))
#     153     # unravel transitions to get states, actions, rewards and next states
#
# Cell In[6], line 63, in ReplayBuffer.sample_minibatch(self, size)
#      61 def sample_minibatch(self, size=100):
#      62     set_weights = self.weights[:self.count] + self.delta
# ---> 63     probabilities = set_weights / sum(set_weights)
#      64     self.indices = np.random.choice(range(self.count), size, p=probabilities, replace=False)
#      65     return self.buffer[self.indices]
#
# KeyboardInterrupt:
