# %% [markdown]
# # RL Acrobot: Simple Policy Gradient PG

# %%
import numpy as np
import gym
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import random

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.optimizers import Adam

# %%
from collections import deque
import time

#---------- Environment and seeds -----------------#


env = gym.make('Acrobot-v1')
input_shape = env.observation_space.shape
n_actions = env.action_space.n
print("Observation space:", input_shape, "n_actions:", n_actions)

tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)
env.action_space.seed(42)  # Ensures deterministic action sampling



#---------- Parameters -----------------#

n_iterations = 300
n_episodes_per_update = 5
n_max_steps = 500
discount_factor = 0.9999
tau = 0.00
learning_rate = 0.01


#---------- Neural nets-----------------#

model = Sequential([
    Dense(32, activation='relu', input_shape=input_shape),
    Dense(32, activation='relu'),
    Dense(n_actions, activation='softmax')                         # Softmax (2 actions)

])

inital_weights = model.get_weights()

# Optimizer and loss
optimizer = Adam(learning_rate=learning_rate)
loss_fn = tf.keras.losses.sparse_categorical_crossentropy



#---------- Neural fast functions-----------------#

@tf.function  # Compile the function for faster execution
def predict_model_fast(state):
    return model(state, training=False)  # Avoids extra TF overhead


#---------- Play Episodes functions -----------------#

def play_multiple_episodes(env, n_episodes, n_max_steps, model, loss_fn):
    all_rewards = []
    all_grads = []
    for episode in range(n_episodes):
        current_rewards = []
        current_grads = []
        obs = env.reset()
        for step in range(n_max_steps):
            obs, reward, done, grads = play_one_step(env, obs, model, loss_fn)
            current_rewards.append(reward)
            current_grads.append(grads)
            if done:
                break
        all_rewards.append(current_rewards)
        all_grads.append(current_grads)
    return all_rewards, all_grads


@tf.function
def compute_loss_and_grads(obs, model, loss_fn):
    with tf.GradientTape() as tape:
    # Get action probabilities from the model
        probas = predict_model_fast(obs[np.newaxis])
        logits = tf.math.log(probas + tf.keras.backend.epsilon())
        action = tf.random.categorical(logits, num_samples=1)
        loss = tf.reduce_mean(loss_fn(action, probas))  # Compute loss

    grads = tape.gradient(loss, model.trainable_variables)  # Compute gradients
    return loss, grads, action

def take_action_and_step(env, action):
    #print(f"Action: {action}")
    action_value = int(action[0, 0].numpy())  # Convert the action tensor to a scalar integer
    #print(f"Action Value: {action_value}")
    obs, reward, done, info = env.step(action_value)  # Perform the action in the environment
    return obs, reward, done, info

def play_one_step(env, obs, model, loss_fn):
    # Compute loss and gradients (with tf.function optimization)
    loss, grads, action = compute_loss_and_grads(obs, model, loss_fn)
    #print(f"Action: {action}")
    # Perform the action in the environment (without tf.function)
    obs, reward, done, info = take_action_and_step(env, action)
    #print(f"Reward: {reward}")

    return obs, reward, done, grads



#---------- Normalization and discount of the rewards -----------------#

def discount_rewards(rewards, discount_factor):
    discounted = np.array(rewards)
    for step in range(len(rewards) - 2, -1, -1):
        discounted[step] += discounted[step + 1] * discount_factor
    return discounted

def discount_and_normalize_rewards(all_rewards, discount_factor):
    all_discounted_rewards = [discount_rewards(rewards, discount_factor) for rewards in all_rewards]
    flat_rewards = np.concatenate(all_discounted_rewards)
    reward_mean = flat_rewards.mean()
    reward_std = flat_rewards.std()
    return [(discounted_rewards - reward_mean) / reward_std for discounted_rewards in all_discounted_rewards]



#---------- Gradient related functions (training) -----------------#

def compute_mean_grads(all_final_rewards, all_grads, model):
    all_mean_grads = []
    
    # Loop over each model's trainable variable
    for var_index in range(len(model.trainable_variables)):
        grad_list = []

        # We need to iterate over the rewards and gradients for each episode and step
        for episode_index, final_rewards in enumerate(all_final_rewards):
            for step, final_reward in enumerate(final_rewards):
                grad = all_grads[episode_index][step][var_index]
                grad_list.append(final_reward * grad)

        # Convert grad_list into a tensor and compute the mean gradient
        grad_tensor = tf.convert_to_tensor(grad_list, dtype=tf.float32)
        mean_grad = tf.reduce_mean(grad_tensor, axis=0)
        all_mean_grads.append(mean_grad)
    
    return all_mean_grads

'''
@tf.function
def apply_gradients(model, all_mean_grads, optimizer):
    optimizer.apply_gradients(zip(all_mean_grads, model.trainable_variables))
'''

def general_gradient(model, all_mean_grads, optimizer, tau = tau):
    apply_gradients(model, all_mean_grads, optimizer)
    soft_update_weights(model, tau=tau)

@tf.function
def apply_gradients(model, all_mean_grads, optimizer, tau=tau):
    # Apply the gradients
    optimizer.apply_gradients(zip(all_mean_grads, model.trainable_variables))
    

def soft_update_weights(model, tau=tau):
    # Perform a soft update on the weights
    current_weights = model.get_weights()
    updated_weights = model.get_weights()  # Get new weights after applying gradients

    # Soft update rule
    new_weights = [tau * updated + (1 - tau) * current for updated, current in zip(updated_weights, current_weights)]
    
    model.set_weights(new_weights)  # Update the model with blended weights



    




#---------- Training -----------------#

env.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

total_rewards_list = []
mean_rewards_list = []
best_score = -np.inf
import time

model.set_weights(inital_weights)

for iteration in range(n_iterations):
    start_time_episodes = time.time()
    all_rewards, all_grads = play_multiple_episodes(env, n_episodes_per_update, n_max_steps, model, loss_fn)
    end_time_episodes = time.time()
    total_rewards = sum(map(sum, all_rewards))
    
    
    total_rewards_list.append(total_rewards/n_episodes_per_update)
    mean_r = np.mean(total_rewards_list[-50:] if len(total_rewards_list) > 50 else total_rewards_list)
    mean_rewards_list.append(mean_r)
    
    print(f"Iteration: {iteration}, Total Rewards per episode: {total_rewards/n_episodes_per_update}, Mean Rewards Training: {mean_r}")

    start_time_discount = time.time()
    all_final_rewards = discount_and_normalize_rewards(all_rewards, discount_factor)
    end_time_discount = time.time()

    # Compute mean gradients (not wrapped in tf.function due to iteration)
    start_time_gradients = time.time()  
    all_mean_grads = compute_mean_grads(all_final_rewards, all_grads, model)

    # Apply gradients using tf.function
    #apply_gradients(model, all_mean_grads, optimizer)
    general_gradient(model, all_mean_grads, optimizer)
    end_time_gradients = time.time()
    #print(f"Episode Time: {end_time_episodes - start_time_episodes}, Discount Time: {end_time_discount - start_time_discount}, Gradient Time: {end_time_gradients - start_time_gradients}")

    if mean_rewards_list[-1] > best_score:
        best_weights = model.get_weights()
        best_score = mean_rewards_list[-1]

# Restore best weights
model.set_weights(best_weights)



# Use Seaborn to plot rewards per episode
sns.set_style("darkgrid")  # Set a nice style
plt.figure(figsize=(10, 5))  # Set figure size

sns.lineplot(x=range(len(total_rewards_list)), y=total_rewards_list, label="Total Reward per Episode")
sns.lineplot(x=range(len(mean_rewards_list)), y=mean_rewards_list, label="Mean Reward (50 episodes)")

plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Training Progress: Rewards per Episode")
plt.legend()
plt.show()
# Out:
# Observation space: (6,) n_actions: 3
# c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Iteration: 0, Total Rewards per episode: -435.0, Mean Rewards Training: -435.0
# Iteration: 1, Total Rewards per episode: -258.8, Mean Rewards Training: -346.9
# Iteration: 2, Total Rewards per episode: -211.4, Mean Rewards Training: -301.7333333333333
# Iteration: 3, Total Rewards per episode: -187.6, Mean Rewards Training: -273.2
# Iteration: 4, Total Rewards per episode: -170.0, Mean Rewards Training: -252.56
# Iteration: 5, Total Rewards per episode: -153.4, Mean Rewards Training: -236.03333333333333
# Iteration: 6, Total Rewards per episode: -168.8, Mean Rewards Training: -226.42857142857142
# Iteration: 7, Total Rewards per episode: -202.0, Mean Rewards Training: -223.375
# Iteration: 8, Total Rewards per episode: -156.0, Mean Rewards Training: -215.88888888888889
# Iteration: 9, Total Rewards per episode: -146.6, Mean Rewards Training: -208.95999999999998
# Iteration: 10, Total Rewards per episode: -119.2, Mean Rewards Training: -200.79999999999998
# Iteration: 11, Total Rewards per episode: -152.0, Mean Rewards Training: -196.73333333333332
# Iteration: 12, Total Rewards per episode: -119.8, Mean Rewards Training: -190.8153846153846
# Iteration: 13, Total Rewards per episode: -131.8, Mean Rewards Training: -186.6
# Iteration: 14, Total Rewards per episode: -110.2, Mean Rewards Training: -181.50666666666666
# Iteration: 15, Total Rewards per episode: -114.2, Mean Rewards Training: -177.3
# Iteration: 16, Total Rewards per episode: -107.0, Mean Rewards Training: -173.16470588235296
# Iteration: 17, Total Rewards per episode: -113.2, Mean Rewards Training: -169.83333333333334
# Iteration: 18, Total Rewards per episode: -143.0, Mean Rewards Training: -168.42105263157896
# Iteration: 19, Total Rewards per episode: -113.4, Mean Rewards Training: -165.67000000000002
# Iteration: 20, Total Rewards per episode: -111.0, Mean Rewards Training: -163.06666666666666
# Iteration: 21, Total Rewards per episode: -92.4, Mean Rewards Training: -159.85454545454547
# Iteration: 22, Total Rewards per episode: -117.8, Mean Rewards Training: -158.02608695652177
# Iteration: 23, Total Rewards per episode: -118.6, Mean Rewards Training: -156.38333333333333
# Iteration: 24, Total Rewards per episode: -84.6, Mean Rewards Training: -153.512
# Iteration: 25, Total Rewards per episode: -83.4, Mean Rewards Training: -150.8153846153846
# Iteration: 26, Total Rewards per episode: -82.2, Mean Rewards Training: -148.27407407407406
# Iteration: 27, Total Rewards per episode: -94.4, Mean Rewards Training: -146.34999999999997
# Iteration: 28, Total Rewards per episode: -80.6, Mean Rewards Training: -144.08275862068965
# Iteration: 29, Total Rewards per episode: -81.2, Mean Rewards Training: -141.98666666666665
# Iteration: 30, Total Rewards per episode: -80.6, Mean Rewards Training: -140.00645161290322
# Iteration: 31, Total Rewards per episode: -83.8, Mean Rewards Training: -138.25
# Iteration: 32, Total Rewards per episode: -81.0, Mean Rewards Training: -136.5151515151515
# Iteration: 33, Total Rewards per episode: -111.0, Mean Rewards Training: -135.76470588235293
# Iteration: 34, Total Rewards per episode: -78.4, Mean Rewards Training: -134.12571428571428
# Iteration: 35, Total Rewards per episode: -83.4, Mean Rewards Training: -132.71666666666664
# Iteration: 36, Total Rewards per episode: -82.8, Mean Rewards Training: -131.36756756756756
# Iteration: 37, Total Rewards per episode: -84.8, Mean Rewards Training: -130.14210526315787
# Iteration: 38, Total Rewards per episode: -83.8, Mean Rewards Training: -128.95384615384614
# Iteration: 39, Total Rewards per episode: -77.4, Mean Rewards Training: -127.665
# Iteration: 40, Total Rewards per episode: -83.6, Mean Rewards Training: -126.59024390243904
# Iteration: 41, Total Rewards per episode: -80.0, Mean Rewards Training: -125.4809523809524
# Iteration: 42, Total Rewards per episode: -80.4, Mean Rewards Training: -124.43255813953489
# Iteration: 43, Total Rewards per episode: -90.0, Mean Rewards Training: -123.65
# Iteration: 44, Total Rewards per episode: -83.2, Mean Rewards Training: -122.75111111111111
# Iteration: 45, Total Rewards per episode: -84.4, Mean Rewards Training: -121.91739130434782
# Iteration: 46, Total Rewards per episode: -83.2, Mean Rewards Training: -121.09361702127659
# Iteration: 47, Total Rewards per episode: -85.8, Mean Rewards Training: -120.35833333333335
# Iteration: 48, Total Rewards per episode: -88.2, Mean Rewards Training: -119.70204081632654
# Iteration: 49, Total Rewards per episode: -81.2, Mean Rewards Training: -118.932
# Iteration: 50, Total Rewards per episode: -78.0, Mean Rewards Training: -111.79199999999999
# Iteration: 51, Total Rewards per episode: -80.0, Mean Rewards Training: -108.21600000000001
# Iteration: 52, Total Rewards per episode: -79.4, Mean Rewards Training: -105.57599999999998
# Iteration: 53, Total Rewards per episode: -83.4, Mean Rewards Training: -103.49199999999998
# Iteration: 54, Total Rewards per episode: -81.2, Mean Rewards Training: -101.71599999999998
# Iteration: 55, Total Rewards per episode: -86.0, Mean Rewards Training: -100.368
# Iteration: 56, Total Rewards per episode: -90.6, Mean Rewards Training: -98.80400000000002
# Iteration: 57, Total Rewards per episode: -70.6, Mean Rewards Training: -96.176
# Iteration: 58, Total Rewards per episode: -85.2, Mean Rewards Training: -94.76000000000002
# Iteration: 59, Total Rewards per episode: -76.0, Mean Rewards Training: -93.348
# Iteration: 60, Total Rewards per episode: -80.8, Mean Rewards Training: -92.58
# Iteration: 61, Total Rewards per episode: -70.6, Mean Rewards Training: -90.95200000000001
# Iteration: 62, Total Rewards per episode: -83.8, Mean Rewards Training: -90.23200000000003
# Iteration: 63, Total Rewards per episode: -88.2, Mean Rewards Training: -89.36
# Iteration: 64, Total Rewards per episode: -81.8, Mean Rewards Training: -88.79199999999999
# Iteration: 65, Total Rewards per episode: -81.0, Mean Rewards Training: -88.12800000000001
# Iteration: 66, Total Rewards per episode: -81.4, Mean Rewards Training: -87.61599999999999
# Iteration: 67, Total Rewards per episode: -88.0, Mean Rewards Training: -87.112
# Iteration: 68, Total Rewards per episode: -84.0, Mean Rewards Training: -85.93199999999999
# Iteration: 69, Total Rewards per episode: -115.8, Mean Rewards Training: -85.98
# Iteration: 70, Total Rewards per episode: -90.0, Mean Rewards Training: -85.56
# Iteration: 71, Total Rewards per episode: -77.6, Mean Rewards Training: -85.26400000000001
# Iteration: 72, Total Rewards per episode: -77.0, Mean Rewards Training: -84.44800000000001
# Iteration: 73, Total Rewards per episode: -119.2, Mean Rewards Training: -84.46
# Iteration: 74, Total Rewards per episode: -92.2, Mean Rewards Training: -84.612
# Iteration: 75, Total Rewards per episode: -87.2, Mean Rewards Training: -84.68799999999999
# Iteration: 76, Total Rewards per episode: -76.8, Mean Rewards Training: -84.58
# Iteration: 77, Total Rewards per episode: -87.0, Mean Rewards Training: -84.432
# Iteration: 78, Total Rewards per episode: -84.4, Mean Rewards Training: -84.508
# Iteration: 79, Total Rewards per episode: -88.4, Mean Rewards Training: -84.65199999999999
# Iteration: 80, Total Rewards per episode: -90.4, Mean Rewards Training: -84.848
# Iteration: 81, Total Rewards per episode: -77.0, Mean Rewards Training: -84.71199999999999
# Iteration: 82, Total Rewards per episode: -102.0, Mean Rewards Training: -85.132
# Iteration: 83, Total Rewards per episode: -84.6, Mean Rewards Training: -84.604
# Iteration: 84, Total Rewards per episode: -82.0, Mean Rewards Training: -84.676
# Iteration: 85, Total Rewards per episode: -93.6, Mean Rewards Training: -84.88
# Iteration: 86, Total Rewards per episode: -90.6, Mean Rewards Training: -85.03600000000002
# Iteration: 87, Total Rewards per episode: -81.8, Mean Rewards Training: -84.976
# Iteration: 88, Total Rewards per episode: -82.0, Mean Rewards Training: -84.94
# Iteration: 89, Total Rewards per episode: -109.4, Mean Rewards Training: -85.58
# Iteration: 90, Total Rewards per episode: -90.4, Mean Rewards Training: -85.71599999999998
# Iteration: 91, Total Rewards per episode: -106.4, Mean Rewards Training: -86.24399999999997
# Iteration: 92, Total Rewards per episode: -81.4, Mean Rewards Training: -86.26399999999998
# Iteration: 93, Total Rewards per episode: -92.0, Mean Rewards Training: -86.304
# Iteration: 94, Total Rewards per episode: -85.6, Mean Rewards Training: -86.352
# Iteration: 95, Total Rewards per episode: -110.2, Mean Rewards Training: -86.86800000000001
# Iteration: 96, Total Rewards per episode: -77.2, Mean Rewards Training: -86.74799999999999
# Iteration: 97, Total Rewards per episode: -93.0, Mean Rewards Training: -86.89200000000001
# Iteration: 98, Total Rewards per episode: -82.0, Mean Rewards Training: -86.76799999999999
# Iteration: 99, Total Rewards per episode: -104.2, Mean Rewards Training: -87.228
# Iteration: 100, Total Rewards per episode: -105.8, Mean Rewards Training: -87.78400000000002
# Iteration: 101, Total Rewards per episode: -103.4, Mean Rewards Training: -88.25200000000001
# Iteration: 102, Total Rewards per episode: -90.8, Mean Rewards Training: -88.48
# Iteration: 103, Total Rewards per episode: -114.6, Mean Rewards Training: -89.10400000000001
# Iteration: 104, Total Rewards per episode: -83.0, Mean Rewards Training: -89.14000000000001
# Iteration: 105, Total Rewards per episode: -81.2, Mean Rewards Training: -89.044
# Iteration: 106, Total Rewards per episode: -83.4, Mean Rewards Training: -88.9
# Iteration: 107, Total Rewards per episode: -93.0, Mean Rewards Training: -89.348
# Iteration: 108, Total Rewards per episode: -88.8, Mean Rewards Training: -89.42000000000002
# Iteration: 109, Total Rewards per episode: -87.4, Mean Rewards Training: -89.648
# Iteration: 110, Total Rewards per episode: -82.2, Mean Rewards Training: -89.67599999999999
# Iteration: 111, Total Rewards per episode: -94.6, Mean Rewards Training: -90.156
# Iteration: 112, Total Rewards per episode: -88.4, Mean Rewards Training: -90.24799999999999
# Iteration: 113, Total Rewards per episode: -110.2, Mean Rewards Training: -90.68799999999999
# Iteration: 114, Total Rewards per episode: -83.0, Mean Rewards Training: -90.71199999999999
# Iteration: 115, Total Rewards per episode: -92.2, Mean Rewards Training: -90.936
# Iteration: 116, Total Rewards per episode: -82.2, Mean Rewards Training: -90.95199999999998
# Iteration: 117, Total Rewards per episode: -94.8, Mean Rewards Training: -91.088
# Iteration: 118, Total Rewards per episode: -87.6, Mean Rewards Training: -91.16000000000003
# Iteration: 119, Total Rewards per episode: -100.0, Mean Rewards Training: -90.84400000000001
# Iteration: 120, Total Rewards per episode: -85.8, Mean Rewards Training: -90.76
# Iteration: 121, Total Rewards per episode: -104.0, Mean Rewards Training: -91.28800000000001
# Iteration: 122, Total Rewards per episode: -87.6, Mean Rewards Training: -91.5
# Iteration: 123, Total Rewards per episode: -101.4, Mean Rewards Training: -91.14399999999999
# Iteration: 124, Total Rewards per episode: -126.0, Mean Rewards Training: -91.82
# Iteration: 125, Total Rewards per episode: -78.0, Mean Rewards Training: -91.63599999999998
# Iteration: 126, Total Rewards per episode: -90.8, Mean Rewards Training: -91.916
# Iteration: 127, Total Rewards per episode: -83.6, Mean Rewards Training: -91.84800000000001
# Iteration: 128, Total Rewards per episode: -83.8, Mean Rewards Training: -91.836
# Iteration: 129, Total Rewards per episode: -102.4, Mean Rewards Training: -92.116
# Iteration: 130, Total Rewards per episode: -85.0, Mean Rewards Training: -92.008
# Iteration: 131, Total Rewards per episode: -95.0, Mean Rewards Training: -92.368
# Iteration: 132, Total Rewards per episode: -95.0, Mean Rewards Training: -92.228
# Iteration: 133, Total Rewards per episode: -135.6, Mean Rewards Training: -93.248
# Iteration: 134, Total Rewards per episode: -79.4, Mean Rewards Training: -93.196
# Iteration: 135, Total Rewards per episode: -102.0, Mean Rewards Training: -93.36399999999999
# Iteration: 136, Total Rewards per episode: -85.6, Mean Rewards Training: -93.26400000000001
# Iteration: 137, Total Rewards per episode: -80.4, Mean Rewards Training: -93.236
# Iteration: 138, Total Rewards per episode: -94.4, Mean Rewards Training: -93.48399999999998
# Iteration: 139, Total Rewards per episode: -111.2, Mean Rewards Training: -93.51999999999998
# Iteration: 140, Total Rewards per episode: -81.4, Mean Rewards Training: -93.33999999999997
# Iteration: 141, Total Rewards per episode: -86.0, Mean Rewards Training: -92.932
# Iteration: 142, Total Rewards per episode: -76.2, Mean Rewards Training: -92.82799999999999
# Iteration: 143, Total Rewards per episode: -77.0, Mean Rewards Training: -92.528
# Iteration: 144, Total Rewards per episode: -83.2, Mean Rewards Training: -92.47999999999998
# Iteration: 145, Total Rewards per episode: -75.8, Mean Rewards Training: -91.792
# Iteration: 146, Total Rewards per episode: -101.2, Mean Rewards Training: -92.272
# Iteration: 147, Total Rewards per episode: -87.8, Mean Rewards Training: -92.16799999999999
# Iteration: 148, Total Rewards per episode: -77.4, Mean Rewards Training: -92.07600000000001
# Iteration: 149, Total Rewards per episode: -81.2, Mean Rewards Training: -91.61599999999999
# Iteration: 150, Total Rewards per episode: -84.8, Mean Rewards Training: -91.196
# Iteration: 151, Total Rewards per episode: -83.2, Mean Rewards Training: -90.792
# Iteration: 152, Total Rewards per episode: -76.8, Mean Rewards Training: -90.512
# Iteration: 153, Total Rewards per episode: -88.4, Mean Rewards Training: -89.988
# Iteration: 154, Total Rewards per episode: -73.4, Mean Rewards Training: -89.79599999999999
# Iteration: 155, Total Rewards per episode: -79.0, Mean Rewards Training: -89.75200000000001
# Iteration: 156, Total Rewards per episode: -81.6, Mean Rewards Training: -89.71600000000002
# Iteration: 157, Total Rewards per episode: -77.2, Mean Rewards Training: -89.4
# Iteration: 158, Total Rewards per episode: -87.4, Mean Rewards Training: -89.37199999999999
# Iteration: 159, Total Rewards per episode: -86.6, Mean Rewards Training: -89.35600000000002
# Iteration: 160, Total Rewards per episode: -93.4, Mean Rewards Training: -89.58
# Iteration: 161, Total Rewards per episode: -151.8, Mean Rewards Training: -90.72399999999999
# Iteration: 162, Total Rewards per episode: -111.0, Mean Rewards Training: -91.176
# Iteration: 163, Total Rewards per episode: -113.8, Mean Rewards Training: -91.248
# Iteration: 164, Total Rewards per episode: -134.4, Mean Rewards Training: -92.27600000000001
# Iteration: 165, Total Rewards per episode: -223.2, Mean Rewards Training: -94.896
# Iteration: 166, Total Rewards per episode: -89.6, Mean Rewards Training: -95.044
# Iteration: 167, Total Rewards per episode: -147.0, Mean Rewards Training: -96.08800000000001
# Iteration: 168, Total Rewards per episode: -149.8, Mean Rewards Training: -97.33200000000001
# Iteration: 169, Total Rewards per episode: -164.0, Mean Rewards Training: -98.61200000000001
# Iteration: 170, Total Rewards per episode: -95.6, Mean Rewards Training: -98.808
# Iteration: 171, Total Rewards per episode: -102.8, Mean Rewards Training: -98.78400000000002
# Iteration: 172, Total Rewards per episode: -109.6, Mean Rewards Training: -99.22400000000002
# Iteration: 173, Total Rewards per episode: -98.0, Mean Rewards Training: -99.156
# Iteration: 174, Total Rewards per episode: -110.0, Mean Rewards Training: -98.836
# Iteration: 175, Total Rewards per episode: -98.2, Mean Rewards Training: -99.24
# Iteration: 176, Total Rewards per episode: -99.6, Mean Rewards Training: -99.416
# Iteration: 177, Total Rewards per episode: -110.8, Mean Rewards Training: -99.96000000000002
# Iteration: 178, Total Rewards per episode: -168.8, Mean Rewards Training: -101.66
# Iteration: 179, Total Rewards per episode: -104.6, Mean Rewards Training: -101.70400000000001
# Iteration: 180, Total Rewards per episode: -129.4, Mean Rewards Training: -102.59200000000001
# Iteration: 181, Total Rewards per episode: -92.8, Mean Rewards Training: -102.54799999999999
# Iteration: 182, Total Rewards per episode: -72.4, Mean Rewards Training: -102.096
# Iteration: 183, Total Rewards per episode: -73.8, Mean Rewards Training: -100.86
# Iteration: 184, Total Rewards per episode: -84.4, Mean Rewards Training: -100.95999999999998
# Iteration: 185, Total Rewards per episode: -106.0, Mean Rewards Training: -101.03999999999998
# Iteration: 186, Total Rewards per episode: -118.4, Mean Rewards Training: -101.69599999999998
# Iteration: 187, Total Rewards per episode: -77.4, Mean Rewards Training: -101.63599999999998
# Iteration: 188, Total Rewards per episode: -88.0, Mean Rewards Training: -101.508
# Iteration: 189, Total Rewards per episode: -77.8, Mean Rewards Training: -100.84
# Iteration: 190, Total Rewards per episode: -84.4, Mean Rewards Training: -100.89999999999998
# Iteration: 191, Total Rewards per episode: -81.2, Mean Rewards Training: -100.80399999999997
# Iteration: 192, Total Rewards per episode: -94.6, Mean Rewards Training: -101.17199999999998
# Iteration: 193, Total Rewards per episode: -87.0, Mean Rewards Training: -101.37200000000001
# Iteration: 194, Total Rewards per episode: -87.4, Mean Rewards Training: -101.45599999999999
# Iteration: 195, Total Rewards per episode: -88.0, Mean Rewards Training: -101.69999999999999
# Iteration: 196, Total Rewards per episode: -80.2, Mean Rewards Training: -101.27999999999999
# Iteration: 197, Total Rewards per episode: -87.0, Mean Rewards Training: -101.264
# Iteration: 198, Total Rewards per episode: -72.0, Mean Rewards Training: -101.15599999999999
# Iteration: 199, Total Rewards per episode: -84.6, Mean Rewards Training: -101.22400000000002
# Iteration: 200, Total Rewards per episode: -79.0, Mean Rewards Training: -101.108
# Iteration: 201, Total Rewards per episode: -76.8, Mean Rewards Training: -100.98
# Iteration: 202, Total Rewards per episode: -75.0, Mean Rewards Training: -100.944
# Iteration: 203, Total Rewards per episode: -90.2, Mean Rewards Training: -100.97999999999998
# Iteration: 204, Total Rewards per episode: -78.0, Mean Rewards Training: -101.072
# Iteration: 205, Total Rewards per episode: -77.2, Mean Rewards Training: -101.03599999999999
# Iteration: 206, Total Rewards per episode: -90.0, Mean Rewards Training: -101.204
# Iteration: 207, Total Rewards per episode: -90.8, Mean Rewards Training: -101.476
# Iteration: 208, Total Rewards per episode: -85.8, Mean Rewards Training: -101.44400000000002
# Iteration: 209, Total Rewards per episode: -77.6, Mean Rewards Training: -101.264
# Iteration: 210, Total Rewards per episode: -75.2, Mean Rewards Training: -100.9
# Iteration: 211, Total Rewards per episode: -90.2, Mean Rewards Training: -99.66799999999999
# Iteration: 212, Total Rewards per episode: -74.2, Mean Rewards Training: -98.93199999999999
# Iteration: 213, Total Rewards per episode: -80.6, Mean Rewards Training: -98.26800000000001
# Iteration: 214, Total Rewards per episode: -102.2, Mean Rewards Training: -97.624
# Iteration: 215, Total Rewards per episode: -86.0, Mean Rewards Training: -94.87999999999998
# Iteration: 216, Total Rewards per episode: -86.4, Mean Rewards Training: -94.81599999999999
# Iteration: 217, Total Rewards per episode: -158.4, Mean Rewards Training: -95.04399999999998
# Iteration: 218, Total Rewards per episode: -87.4, Mean Rewards Training: -93.79599999999999
# Iteration: 219, Total Rewards per episode: -76.0, Mean Rewards Training: -92.03599999999999
# Iteration: 220, Total Rewards per episode: -77.2, Mean Rewards Training: -91.668
# Iteration: 221, Total Rewards per episode: -82.8, Mean Rewards Training: -91.26799999999999
# Iteration: 222, Total Rewards per episode: -90.6, Mean Rewards Training: -90.888
# Iteration: 223, Total Rewards per episode: -83.8, Mean Rewards Training: -90.60400000000001
# Iteration: 224, Total Rewards per episode: -76.6, Mean Rewards Training: -89.936
# Iteration: 225, Total Rewards per episode: -89.2, Mean Rewards Training: -89.756
# Iteration: 226, Total Rewards per episode: -80.0, Mean Rewards Training: -89.36399999999999
# Iteration: 227, Total Rewards per episode: -86.6, Mean Rewards Training: -88.88000000000002
# Iteration: 228, Total Rewards per episode: -95.0, Mean Rewards Training: -87.40400000000001
# Iteration: 229, Total Rewards per episode: -80.8, Mean Rewards Training: -86.92800000000001
# Iteration: 230, Total Rewards per episode: -79.6, Mean Rewards Training: -85.932
# Iteration: 231, Total Rewards per episode: -88.6, Mean Rewards Training: -85.84800000000003
# Iteration: 232, Total Rewards per episode: -88.6, Mean Rewards Training: -86.17200000000001
# Iteration: 233, Total Rewards per episode: -85.4, Mean Rewards Training: -86.40400000000001
# Iteration: 234, Total Rewards per episode: -90.6, Mean Rewards Training: -86.52799999999999
# Iteration: 235, Total Rewards per episode: -82.0, Mean Rewards Training: -86.04800000000002
# Iteration: 236, Total Rewards per episode: -79.6, Mean Rewards Training: -85.272
# Iteration: 237, Total Rewards per episode: -79.8, Mean Rewards Training: -85.32000000000002
# Iteration: 238, Total Rewards per episode: -78.8, Mean Rewards Training: -85.13600000000001
# Iteration: 239, Total Rewards per episode: -89.8, Mean Rewards Training: -85.37600000000002
# Iteration: 240, Total Rewards per episode: -85.8, Mean Rewards Training: -85.404
# Iteration: 241, Total Rewards per episode: -81.8, Mean Rewards Training: -85.416
# Iteration: 242, Total Rewards per episode: -84.6, Mean Rewards Training: -85.21600000000001
# Iteration: 243, Total Rewards per episode: -87.2, Mean Rewards Training: -85.22
# Iteration: 244, Total Rewards per episode: -91.8, Mean Rewards Training: -85.308
# Iteration: 245, Total Rewards per episode: -87.8, Mean Rewards Training: -85.304
# Iteration: 246, Total Rewards per episode: -101.0, Mean Rewards Training: -85.72
# Iteration: 247, Total Rewards per episode: -97.6, Mean Rewards Training: -85.932
# Iteration: 248, Total Rewards per episode: -91.0, Mean Rewards Training: -86.31200000000001
# Iteration: 249, Total Rewards per episode: -98.4, Mean Rewards Training: -86.588
# Iteration: 250, Total Rewards per episode: -87.4, Mean Rewards Training: -86.75599999999999
# Iteration: 251, Total Rewards per episode: -78.6, Mean Rewards Training: -86.792
# Iteration: 252, Total Rewards per episode: -99.0, Mean Rewards Training: -87.272
# Iteration: 253, Total Rewards per episode: -81.2, Mean Rewards Training: -87.09200000000001
# Iteration: 254, Total Rewards per episode: -96.8, Mean Rewards Training: -87.46799999999999
# Iteration: 255, Total Rewards per episode: -86.0, Mean Rewards Training: -87.64399999999999
# Iteration: 256, Total Rewards per episode: -90.0, Mean Rewards Training: -87.64399999999999
# Iteration: 257, Total Rewards per episode: -109.0, Mean Rewards Training: -88.008
# Iteration: 258, Total Rewards per episode: -120.8, Mean Rewards Training: -88.708
# Iteration: 259, Total Rewards per episode: -86.0, Mean Rewards Training: -88.876
# Iteration: 260, Total Rewards per episode: -91.2, Mean Rewards Training: -89.19599999999998
# Iteration: 261, Total Rewards per episode: -109.6, Mean Rewards Training: -89.584
# Iteration: 262, Total Rewards per episode: -104.4, Mean Rewards Training: -90.18799999999999
# Iteration: 263, Total Rewards per episode: -113.8, Mean Rewards Training: -90.85199999999999
# Iteration: 264, Total Rewards per episode: -136.4, Mean Rewards Training: -91.53599999999999
# Iteration: 265, Total Rewards per episode: -89.6, Mean Rewards Training: -91.60799999999999
# Iteration: 266, Total Rewards per episode: -90.4, Mean Rewards Training: -91.68799999999999
# Iteration: 267, Total Rewards per episode: -93.8, Mean Rewards Training: -90.396
# Iteration: 268, Total Rewards per episode: -85.4, Mean Rewards Training: -90.35600000000001
# Iteration: 269, Total Rewards per episode: -91.8, Mean Rewards Training: -90.67199999999998
# Iteration: 270, Total Rewards per episode: -82.0, Mean Rewards Training: -90.76800000000001
# Iteration: 271, Total Rewards per episode: -107.6, Mean Rewards Training: -91.26400000000001
# Iteration: 272, Total Rewards per episode: -86.2, Mean Rewards Training: -91.176
# Iteration: 273, Total Rewards per episode: -77.0, Mean Rewards Training: -91.04
# Iteration: 274, Total Rewards per episode: -92.6, Mean Rewards Training: -91.36
# Iteration: 275, Total Rewards per episode: -86.4, Mean Rewards Training: -91.304
# Iteration: 276, Total Rewards per episode: -73.8, Mean Rewards Training: -91.17999999999998
# Iteration: 277, Total Rewards per episode: -74.8, Mean Rewards Training: -90.94400000000002
# Iteration: 278, Total Rewards per episode: -87.4, Mean Rewards Training: -90.79199999999999
# Iteration: 279, Total Rewards per episode: -79.6, Mean Rewards Training: -90.76799999999999
# Iteration: 280, Total Rewards per episode: -80.4, Mean Rewards Training: -90.78399999999999
# Iteration: 281, Total Rewards per episode: -72.2, Mean Rewards Training: -90.456
# Iteration: 282, Total Rewards per episode: -76.2, Mean Rewards Training: -90.208
# Iteration: 283, Total Rewards per episode: -82.0, Mean Rewards Training: -90.14
# Iteration: 284, Total Rewards per episode: -81.2, Mean Rewards Training: -89.95199999999998
# Iteration: 285, Total Rewards per episode: -82.2, Mean Rewards Training: -89.95599999999999
# Iteration: 286, Total Rewards per episode: -84.4, Mean Rewards Training: -90.05199999999999
# Iteration: 287, Total Rewards per episode: -77.6, Mean Rewards Training: -90.00800000000001
# Iteration: 288, Total Rewards per episode: -80.2, Mean Rewards Training: -90.036
# Iteration: 289, Total Rewards per episode: -96.6, Mean Rewards Training: -90.17200000000001
# Iteration: 290, Total Rewards per episode: -77.2, Mean Rewards Training: -90.00000000000001
# Iteration: 291, Total Rewards per episode: -77.6, Mean Rewards Training: -89.916
# Iteration: 292, Total Rewards per episode: -78.0, Mean Rewards Training: -89.78400000000002
# Iteration: 293, Total Rewards per episode: -178.0, Mean Rewards Training: -91.6
# Iteration: 294, Total Rewards per episode: -87.0, Mean Rewards Training: -91.50400000000002
# Iteration: 295, Total Rewards per episode: -90.2, Mean Rewards Training: -91.55199999999999
# Iteration: 296, Total Rewards per episode: -106.2, Mean Rewards Training: -91.65599999999999
# Iteration: 297, Total Rewards per episode: -74.8, Mean Rewards Training: -91.2
# Iteration: 298, Total Rewards per episode: -81.2, Mean Rewards Training: -91.00400000000002
# Iteration: 299, Total Rewards per episode: -93.4, Mean Rewards Training: -90.904

# %%
# For plotting the animated video
import matplotlib.animation as animation
import matplotlib as mpl
mpl.rc('animation', html='jshtml')


def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames, repeat=False, interval=1):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    plt.close()
    return anim

env = gym.make('Acrobot-v1', render_mode="rgb_array")
state = env.reset()
random.seed(None)  # Reset to default, random state
np.random.seed(None)
tf.random.set_seed(None)


frames = []
total_reward = 0
average_reward = 0
total_rewards = 0

# Interact with the environment using the trained model
for i in range(2):
    total_reward = 0
    obs = env.reset()
    for step in range(n_max_steps):
        # Get action probabilities from the model
        probas = predict_model_fast(state[np.newaxis])  # Assuming your model accepts the observation in the correct format
        logits = tf.math.log(probas + tf.keras.backend.epsilon())
        action = tf.random.categorical(logits, num_samples=1)
        state, reward, done, info = env.step(action[0, 0].numpy())
        total_reward += reward
    
        if done:
            break
        frames.append(env.render(mode="rgb_array"))  # Collect frames for animation
    total_rewards += total_reward
    average_reward = total_rewards / (i+ 1)
    print(f"Episode: {i+1}, Total Reward:{total_reward}, Mean Reward: {average_reward}")
plot_animation(frames)

# Close the environment
#env.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 21
#      18     plt.close()
#      19     return anim
# ---> 21 env = gym.make('Acrobot-v1', render_mode="rgb_array")
#      22 state = env.reset()
#      23 random.seed(None)  # Reset to default, random state
#
# File c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\gym\envs\registration.py:676, in make(id, **kwargs)
#     675 def make(id: str, **kwargs) -> "Env":
# --> 676     return registry.make(id, **kwargs)
#
# File c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\gym\envs\registration.py:520, in EnvRegistry.make(self, path, **kwargs)
#     518 spec = self.spec(path)
#     519 # Construct the environment
# --> 520 return spec.make(**kwargs)
#
# File c:\Users\pierg\Desktop\VirtualEnvironments\Standard_env\Lib\site-packages\gym\envs\registration.py:140, in EnvSpec.make(self, **kwargs)
#     138 else:
#     139     cls = load(self.entry_point)
# --> 140     env = cls(**_kwargs)
#     142 # Make the environment aware of which spec it came from.
#     143 spec = copy.deepcopy(self)
#
# TypeError: AcrobotEnv.__init__() got an unexpected keyword argument 'render_mode'
